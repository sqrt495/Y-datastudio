# %% [markdown]
# **Сергей, привет!**
#
# Предлагаю общаться на «ты». Если это неприемлемо, будет здорово, если я об этом узнаю, и мы перейдем на «вы». Спасибо, что прислал часть проекта для проверки. Для удобства я оставлю комментарии в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Пожалуйста, не перемещай, не изменяй и не удаляй их - так наше общение будет более продуктивным. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий ревьюера</b>
#
# Так выделены самые важные замечания. Без их отработки мы не сможем пройти дальше.
# </div>
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера</b>
#
# Так выделены небольшие замечания или рекомендации. Будет здорово, если они будут учтены в проекте.
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера</b>
#
# Так выделены все остальные комментарии, включая позитивные моменты.
# </div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если комментарии будут как-то выделены.
#
# <div class="alert alert-info">
# <b>Комментарий аналитика</b>
#
# Например, вот так.
# </div>
#
# ---
#
# <div class="alert alert-warning">
# <b>Общий комментарий 1</b>
#
# Сергей, я посмотрел базовую часть - в целом все идет в нужном ключе, в глобальном смысле - результаты получены. Но, нам следует придерживаться более строгого оформления тетрадки и проекта. Код должен содержать комментарии, каждый логический блок, который приводит к какому-то результату должен заканчиваться конкретными выводами, интерпретацией данных. Также следи, пожалуйста, чтобы каждый вывод имел под собой основание в виде результата исследования данных. В проекте очень не хватает объяснений и комментариев к тому, что мы делаем и главное – зачем? Все это отличает просто проект с расчетами от аналитического проекта. Посмотри, пожалуйста, более детально мои комментарии.
#
# <br>
# С наилучшими пожеланиями,
# <br>
# Алексей Каргин
# </div>
#
# ---
#
#
#
#
# <div class="alert alert-info">
# <b>Добрый день, Алексей, расширил и адаптировал офрмление.</b>
# </div>

# %% [markdown]
# <font color='red'>
# Однако, как и в любом проекте, отчете, публикации или научной статье, введение одно из важных частей, поскольку оно должно содержать всю необходимую информацию, которая поможет коллегам или заказчику лучше ориентироваться и понимать основную цель. Также хорошее введение показывает, насколько аналитик понимает поставленные перед ним задачи.
#
# В нашем проекте введение следует расширить:
# - краткое описание проекта - с какими данными и для кого мы будем проводить анализ данных;
# - конкретная постановка основной цели проекта и задач, которые мы будем решать, чтобы эту цель достичь;
# - описание исходных данных (оно есть);
# - также следует добавить краткий план анализа данных (или содержание).
#
# Эти пункты должны ответить на простой вопрос – зачем мы проводим анализ данных и какие задачи, необходимые заказчику, мы должны решить. При форматировании желательно использовать все возможности оформления Markdown. Также, в эту часть проекта можно добавить документацию, в которой будет отображена вся необходимая техническая информация (если не предусмотрено Заказчик этого исследования — Министерство культуры Российской Федерации.
#
# Помимо этого, в финальную версию проекта, можно добавить короткую аннотацию полученных результатов.
# </font>

# %% [markdown]
# <font color='red'>
# Вам нужно изучить рынок российского кинопроката и выявить текущие тренды. Уделите внимание фильмам, которые получили государственную поддержку. Попробуйте ответить на вопрос, насколько такие фильмы интересны зрителю.
#
# Вы будете работать с данными, опубликованными на [портале открытых данных Министерства культуры](http://opendata.mkrf.ru). Набор данных содержит информацию о прокатных удостоверениях, сборах и государственной поддержке фильмов, а также информацию с сайта КиноПоиск.
#
# Примеры заданий, с которыми вы встретитесь:
# 1) Откройте файлы с данными и объедините их в один датафрейм
# (например, Объедините данные таким образом, чтобы все объекты из датасета mkrf_movies обязательно вошли в получившийся датафрейм. )
#
# 2) Предобработка данных
# (например, Изучите столбцы, которые хранят количественные значения. Проверьте, обнаружились ли в таких столбцах подозрительные данные. Как с такими данными лучше поступить?)
#
# 3) Проведите исследовательский анализ данных
# (например, Определите, влияет ли возрастное ограничение аудитории («6+», «12+», «16+», «18+» и т. д.) на сборы фильма в прокате в период с 2015 по 2019 год? Фильмы с каким возрастным ограничением собрали больше всего денег в прокате? Меняется ли картина в зависимости от года? Если да, предположите, с чем это может быть связан)
#
# 4) Исследуйте фильмы, которые получили государственную поддержку
# (На этом этапе нет конкретных инструкций и заданий — поищите интересные закономерности в данных. Посмотрите, сколько выделяют средств на поддержку кино. Проверьте, хорошо ли окупаются такие фильмы, какой у них рейтинг. )
# </font>

# %% [markdown]
# # Исследование "Оценка качества кинопроизводства". Введение<a class="anchor" id="intro"></a>
#
# Заказчик исследования: Министерство культуры Российской Федерации
#
# Основная цель: изучить рынок российского кинопроката, уделить особое внимание фильмам, которые получили государственную поддержку, выявить текущие тренды. Необходимо ответить на вопрос: "Насколько зрителю интересны фильмы с государственной поддержкой?"
#
# В качестве погружения в специфику объекта исследования использовались материалы:
#
# **1. Ведомости, февраль 2019** // [В ГД обсудили эффективность господдержки кинематографа и проблемы кинообразования](http://duma.gov.ru/news/29768/) //
#
# **2. lent.ru, июль 2019**, [Как прокатные удостоверения позволили Минкульту подмять под себя кино в России](https://lenta.ru/articles/2019/07/12/prokat/)
#
# **3. Ведомости, сентябрь 2020**, [2021 год станет для российского кинорынка рекордным](https://www.vedomosti.ru/media/characters/2020/09/01/838465-dlya-kinorinka-rekordnim)
#
#
#
# ### Базовые исследования предоставленных данных (в том числе произведена оценка качества и объема предоставленных наборов данных):
#
# [В каком году медианная сумма сборов была максимальной?](#basic_task_1_ans)
#
# [Через сводную таблицу отразить среднюю и медианную сумму сборов для каждого года.](#basic_task_2_ans)
#
# [У кого из продюссеров самый высокий средний рейтинг фильмов? ](#basic_task_3_ans)
#
#
#
#
#
# Далее предложен и реализован алгоритм моделирования оценки качества кинопроизводителя. В процессе исследования предложены решения по вопросам:
#
# 1. Решена проблемы пропусков данных и недостаточности выборки с помощью внешних источников.
#
#
# 2. ВЫделены факторы имющие наибольшее влияние на показатели рейтинга и кассовых сборов фильма.
# * Какой жанр (все жанры, к которым относится фильм) имеет наибольший рейтинг?
# * Влияет ли возрастное ограничение на успех фильма?
# * Какие фильмы лучше - с господдержкой или без?
#
# 2. Велик ли объем господдержки в фильмах? (надо посчитать долю для каждого фильма и обосновать много это или мало)
#
# 3. Каких продюсеров можно назвать "восходящими звездами кинематографа?" (предложить показатель успешности и проанализовать динамику этого показателя)
#
# 4. Сейчас наши коллеги-аналитики работают с данными в Экселе и тратят много времени на обработку. Данные проекта - результат из работы. Ваша задача указать проблемы в данных, которые они упустили. И показать преимущества pandas для подобных задач.
#
# 5. Постройте модель предсказания будущего рейтинга фильма или успешности в финансовых показателях.<font color='green'></font>
#
#
# Техническая реализация исследования выполнена на python, необходимые зависимости для корректной работы данного документа описаны в разделе [Техническая информация о реализации](#tech). Так же предложены варианты реализации построения модели машинного обучения, для изучения показателей в дианмике.
#
# Пользуйтесь навигацией ниже.

# %% [markdown]
# # <center>*Contents:* </center><a class="anchor" id="contents"></a>
#
#
# ## [Введение](#intro)
#
# ## [Техническая информация о реализации](#tech)
#
# ## [1. Анализ исходных данных](#dive_in)
#
# ## [2. Знакомство с данными и предобработка, решения по обогащению набора данных](#basic_task_0)
#
# [2.1.  Базовый ряд исследований: Посчитайте динамику сборов по годам премьер фильмов. В каком году медианная сумма сборов была максимальной?](#basic_task_1)
#
# [2.2. Базовый ряд исследований. Определить среднюю и медианную сумму сборов для каждого года, результат отразить в сводной таблице.](#basic_task_2)
#
# [2.3. Базовый ряд исследований. У кого из продюссеров самый высокий средний рейтинг фильмов? ](#basic_task_3)
#
#
# ## [HERE](#here)
#
# 3. fast analisys
#
# 4. preparing data
#
# 5. stack data / cloud / sql / parsing process
#
# 6. basic report / dashbord with plotly ?
#
#
# * хочу разместить БД по фильмам в Google Cloude;
# * в БД накапливать/парсить данные - использовать Silenium;
# * там же собрать модель для оценки успешных продюссеров и продюссерских коллективов.
#
#
#
#
# 7. model description
#
# 8. ml poress

# %% [markdown]
# ## Техническая информация о реализации исследования
# <a class="anchor" id="tech"></a>
#
# [<назад](#intro) | [оглавление](#contents) | [дальше>](#dive_in)
#
#
# Версии ПО используемого в проекте указаны в файле **requirements.txt**

# %%
import sys
import json
import pkg_resources
import types
import os
import pandas as pd
import matplotlib as plt
import seaborn as sns
import numpy as np
import re
import datetime
from fuzzywuzzy import process
from fuzzywuzzy import fuzz
from bs4 import BeautifulSoup

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# print(sys.version)
# !pip3 freeze

# %% [markdown]
# ## Исходные предоставленные данные:
#
# #### Получено 2 таблицы в формате `csv`, общая техническая информация о файлах и таблицах:
#
# #### `mkrf_movies.csv`:
#
# * размер файла: менее 1 mb;
# * размер таблицы: 7486 строк Х 14 столбцов.
#
# Таблица содержит информацию из реестра прокатных удостоверений. У одного фильма может быть несколько прокатных удостоверений.
#
# - `title` — название фильма;
# - `puNumber` — номер прокатного удостоверения;
# - `show_start_date` — дата премьеры фильма;
# - `type` — тип фильма;
# - `film_studio` — студия-производитель;
# - `production_country` — страна-производитель;
# - `director` — режиссёр;
# - `producer` — продюсер;
# - `age_restriction` — возрастная категория;
# - `refundable_support` *—* объём возвратных средств государственной поддержки;
# - `nonrefundable_support` *—* объём невозвратных средств государственной поддержки;
# - `financing_source` *—* источник государственного финансирования;
# - `budget` *—* общий бюджет фильма, **уже включает в себя полный объём государственной поддержки. Данные в этом столбце указаны только для тех фильмов, которые получили государственную поддержку.
# - `ratings` *—* рейтинг фильма на КиноПоиске;
# - `genres` *—* жанр фильма.

# %%
mkrf_movies = pd.read_csv('mkrf_movies.csv')
mkrf_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7486 entries, 0 to 7485
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   object
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
# ...

# %% [markdown]
# #### `mkrf_shows.csv`:
#
# * размер файла: менее 50 kb;
# * размер таблицы: 3158 строк Х 2 столбца.
#
# признаки:
# - `puNumber` — номер прокатного удостоверения;
# - `box_office` — сборы в рублях.

# %%
mkrf_shows = pd.read_csv('mkrf_shows.csv')
mkrf_shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3158 entries, 0 to 3157
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   puNumber    3158 non-null   int64
#  1   box_office  3158 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 49.5 KB

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера</b>
#
# Хорошо, что проект начитается с названия и информации об исходных данных.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера</b>
#
# Однако, как и в любом проекте, отчете, публикации или научной статье, введение одно из важных частей, поскольку оно должно содержать всю необходимую информацию, которая поможет коллегам или заказчику лучше ориентироваться и понимать основную цель. Также хорошее введение показывает, насколько аналитик понимает поставленные перед ним задачи.
#
# В нашем проекте введение следует расширить:
# - краткое описание проекта - с какими данными и для кого мы будем проводить анализ данных;
# - конкретная постановка основной цели проекта и задач, которые мы будем решать, чтобы эту цель достичь;
# - описание исходных данных (оно есть);
# - также следует добавить краткий план анализа данных (или содержание).
#
# Эти пункты должны ответить на простой вопрос – зачем мы проводим анализ данных и какие задачи, необходимые заказчику, мы должны решить. При форматировании желательно использовать все возможности оформления Markdown. Также, в эту часть проекта можно добавить документацию, в которой будет отображена вся необходимая техническая информация (если не предусмотрено отдельного readme файла).
#
# Помимо этого, в финальную версию проекта, можно добавить короткую аннотацию полученных результатов.
#
# ---
#
# Пожалуйста, проработай более детально введение к проекту.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера</b>
#
# Хорошо, что импорт библиотек, используемых в проекте, проведен в первой ячейке кода - так коллегам или заказчику будет понятнее, какие библиотеки используются в проекте, и при необходимости настроить окружение для корректного запуска проекта.
# </div>

# %% [markdown]
# ## 1. Анализ исходных данных
# <a class="anchor" id="dive_in"></a>
#
# [<назад](#tech) | [оглавление](#contents) | [дальше>](#basic_task_0)
#
#
# Посмотрим на типы данных и заполненность признаков:

# %%
mkrf_shows.describe(include='all').T
# Out:
#              count          mean           std          min           25%  \
# puNumber    3158.0  1.201875e+08  1.238394e+07  111000113.0  1.130002e+08
# box_office  3158.0  7.647870e+07  2.403531e+08          0.0  8.623900e+04
#
#                      50%           75%           max
# puNumber    1.210131e+08  1.210283e+08  2.240264e+08
# box_office  2.327988e+06  2.397967e+07  3.073569e+09

# %%
mkrf_movies.describe(include='all').T
# Out:
#                        count unique                              top  freq  \
# title                   7486   6772          День святого Валентина_     5
# puNumber                7486   7484                        221054410     2
# show_start_date         7486   1965         2010-12-17T12:00:00.000Z    96
# type                    7486      8                   Художественный  4520
# film_studio             7468   5490            Киностудия "Мосфильм"   341
# production_country      7484    950                              США  2172
# director                7477   4811                       О.Семёнова    47
# producer                6918   5349                        П.Смирнов    67
# age_restriction         7486      5  «16+» - для детей старше 16 лет  2851
# refundable_support     332.0    NaN                              NaN   NaN
# nonrefundable_support  332.0    NaN                              NaN   NaN
# ...

# %% [markdown]
# Мы можем объединить 2 таблицы, предварительно убедишись, что `mkrf_shows` содержить только уникальные `puNumber` номера прокатных удостоверений. Далее приведем `puNumber` к типу строковых данных и выполним слияние таблиц:

# %%
print(f'Кол-во строк в таблице = {mkrf_shows.shape[0]}, \
кол-во уникальных элементов в столбце puNumber = {len(mkrf_shows.puNumber.unique())}.')
# Out:
# Кол-во строк в таблице = 3158, кол-во уникальных элементов в столбце puNumber = 3158.

# %%
mkrf_shows['puNumber'] = mkrf_shows['puNumber'].astype(str)
mkrf_merge = mkrf_movies.merge(mkrf_shows, how='left', on='puNumber').copy()

# %% [markdown]
# Качественно сопоставились и все 3158 значений по кассовым сборам нашли свою пару, тем не меннее обнаружено много пропусков в исходных данных:

# %%
show_percent_dict = {}

for _ in mkrf_merge.columns.tolist():
    percent = (mkrf_merge[mkrf_merge[_].isna()].shape[0] / mkrf_merge.shape[0]) * 100
    show_percent_dict[_] = percent

show_percent_dict = dict(sorted(show_percent_dict.items(), key=lambda x: x[1], reverse=True))
    
print(f'Всего строк в наборе данных: {mkrf_merge.shape[0]}\n')

for k,v in show_percent_dict.items():  
    v = str(int(v)) + '%'
    print(f'{v} - доля пропусков в столбце {k}')
# Out:
# Всего строк в наборе данных: 7486
#
# 95% - доля пропусков в столбце refundable_support
# 95% - доля пропусков в столбце nonrefundable_support
# 95% - доля пропусков в столбце budget
# 95% - доля пропусков в столбце financing_source
# 57% - доля пропусков в столбце box_office
# 13% - доля пропусков в столбце genres
# 12% - доля пропусков в столбце ratings
# 7% - доля пропусков в столбце producer
# 0% - доля пропусков в столбце film_studio
# 0% - доля пропусков в столбце director
# 0% - доля пропусков в столбце production_country
# 0% - доля пропусков в столбце title
# 0% - доля пропусков в столбце puNumber
# 0% - доля пропусков в столбце show_start_date
# 0% - доля пропусков в столбце type
# 0% - доля пропусков в столбце age_restriction

# %% [markdown]
# Еще несколько вывыодов по полученному набору данных:
#
# 1. Всего 6772 уникальных наименований фильмов.
#
# 2. Большая часть значений в столбцах представлена в виде строковых значений. Значения некоторых признаки нам необходимо первести в иные форматы, а именно:
#
# `puNumber` - изменить на предоставление данных в числовом формате,
#
# `show_start_date` - выделить дату из строки,
#
# `ratings` - изменить на предоставление данных в числовом формате.
#
# 3. Числовые значения содержат столбцы:
# `refundable_support`,
# `nonrefundable_support`,
# `budget`,
# `box_office`
#
# 4. Необходимо указать, что ключевой сущьностью (с уникальным индексом), которую мы хотим далее исследовать считается `puNumber`/ номер прокатного удостоверения. Данные о бюджете и объеме пооддержки есть у 332 прокатных удостоверений картин - этого очень мало для качественного исследования зависимостей этого показателя.
#
# 5. Данные о рейтинге получили 6519 прокатных удостоверения - 88% прокатных удостоверений.
#
# 6. Существует 950 варианта нименования страны производства фильма - это довольно много.
#
# 7. Существует 742 варианта нименования жанра фильма, еесли грубо обощать "на каждые 10 фильмов есть свой жанр" - это довольно много, необходимо будет обощить данные в будущем.
#
#
# Подробнее информация отображена в таблице ниже:

# %%
mkrf_merge.describe(include='all').T
# Out:
#                         count unique                              top  freq  \
# title                    7486   6772          День святого Валентина_     5
# puNumber                 7486   7484                        221054410     2
# show_start_date          7486   1965         2010-12-17T12:00:00.000Z    96
# type                     7486      8                   Художественный  4520
# film_studio              7468   5490            Киностудия "Мосфильм"   341
# production_country       7484    950                              США  2172
# director                 7477   4811                       О.Семёнова    47
# producer                 6918   5349                        П.Смирнов    67
# age_restriction          7486      5  «16+» - для детей старше 16 лет  2851
# refundable_support      332.0    NaN                              NaN   NaN
# nonrefundable_support   332.0    NaN                              NaN   NaN
# ...

# %%
prob = mkrf_merge.describe(include='all').loc['unique',
                                            'production_country'] / mkrf_merge.describe(include='all').loc['count',
                                                                                          'production_country'] 

print(f"Доля уникальных значений в столбце 'production_country' состоявляет\n{prob:.0%} от общего кол-ва\
значений для столбца - это довольно много!")
# Out:
# Доля уникальных значений в столбце 'production_country' состоявляет
# 13% от общего кол-вазначений для столбца - это довольно много!

# %%
prob = mkrf_merge.describe(include='all').loc['unique',
                                            'genres'] / mkrf_merge.describe(include='all').loc['count',
                                                                                          'genres'] 

print(f"Доля уникальных значений в столбце 'ganres' состоявляет\n{prob:.0%} \
от общего кол-ва значений для столбца - это довольно много!")
# Out:
# Доля уникальных значений в столбце 'ganres' состоявляет
# 11% от общего кол-ва значений для столбца - это довольно много!

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера</b>
#
# Отлично, данные были успешно загружены, основная информация по ним выведена. Хорошо, что пропуски были обнаружены, их действительно очень много и разбираться с ними мы будем ниже. Также позитивный момент, что для фильмов, у которых известна сумма сбора, есть и другая информация.
# </div>
#
# <div class="alert alert-danger">
# <b>Комментарий ревьюера</b>
#
# Однако есть несколько моментов, которые надо усилить. В этом блоке мы должны изучить типы данных и оценить их корректность. Чем больше мы знаем о данных – тем более надёжные выводы мы получаем, так как мы можем контролировать влияние на результат каких-либо ошибок. В целом информацию по данным мы вывели выше, но никак не оценили корректность типов, да и сами данные. Также мы вывели результат метода `describe()`, но не интерпретировали их. Старайся не оставлять заказчика один на один с выводами и результатами. Если мы что-то сделали, рассчитали, посмотрели, построили - лучше сопроводить какой-то интерпретацией полученных данных.
#
# Пожалуйста, добавь краткую характеристику данных с оценкой корректности типов данных и предположением, как мы будем обрабатывать эти данные, а также прокомментируй результаты, которые мы получили в этом блоке (например, результат метода `describe()`).
#
# </div>
#
#
# ### Болле подробно расммотрим все признаки. Если перевернуть таблицу на 90 градусов она будет иметь следующий вид (левый столбец это порядок колонок таблицы):

# %%
# изменен порядок расположения столбцов в таюлице:
mkrf_merge = mkrf_merge[['puNumber',
                            'show_start_date',
                            'ratings',
                         
                            'type',
                            'genres',
                            'age_restriction',

                            'title',
                            'film_studio',
                            'production_country',
                            'director',
                            'producer',

                            'financing_source',
                            'refundable_support',
                            'nonrefundable_support',
                            'budget',

                            'box_office']]

mkrf_merge = mkrf_merge.reset_index(drop=True)
mkrf_merge.sample(3).T
# Out:
#                                                          6451  \
# puNumber                                            112013818
# show_start_date                      2018-11-30T12:00:00.000Z
# ratings                                                   7.2
# type                                           Документальный
# genres                         мелодрама,семейный,приключения
# age_restriction               «12+» - для детей старше 12 лет
# title                                                    Путь
# film_studio            ООО "Киновидеостудия "Цветной бульвар"
# production_country                                     Россия
# director                                             В.Орехов
# producer                                              С.Гусев
# financing_source                                          NaN
# refundable_support                                        NaN
# nonrefundable_support                                     NaN
# ...

# %% [markdown]
# 1) Номер прокатного удостоверения `puNumber` —  мы хотели бы использовать как ключевую сущность. В исходных данных присутствуют дубли по данному признаку (вывдено ниже), [изучим природу 2-х пар дублей и примем решение чуть позже](#basic_task_0).

# %%
mkrf_merge[mkrf_merge.duplicated(subset='puNumber', keep=False)].iloc[:,:-7].T
# Out:
#                                                                  4638  \
# puNumber                                                    221154310
# show_start_date                              2010-12-17T12:00:00.000Z
# ratings                                                           7.0
# type                                                   Художественный
# genres                                              мелодрама,комедия
# age_restriction                       «16+» - для детей старше 16 лет
# title                                Как жениться и остаться холостым
# film_studio         Ше Вам, Скрипт Ассосье, Тэ Фэ 1 Фильм Продюксь...
# production_country                                            Франция
#
#                                                                  4639  \
# puNumber                                                    221154310
# show_start_date                              2010-12-17T12:00:00.000Z
# ...

# %% [markdown]
# При попытке привести значения ячеек к числовому типу, чтобы снизить размер обрабатываемых данных - видим, что один из фильмов `Курбан-роман. (История с жертвой)` имеет значение прокатного удостоверения `нет` - посмотрим явно в таблице:

# %%
mkrf_merge.iloc[1797,:]
# Out:
# puNumber                                               нет
# show_start_date                   2014-05-15T12:00:00.000Z
# ratings                                                NaN
# type                                        Художественный
# genres                                                 NaN
# age_restriction            «12+» - для детей старше 12 лет
# title                    Курбан-роман. (История с жертвой)
# film_studio                               ФОНД "ИННОВАЦИЯ"
# production_country                                  Россия
# director                                           С.Юзеев
# producer                                        М.Галицкая
# financing_source                                       NaN
# refundable_support                                     NaN
# nonrefundable_support                                  NaN
# budget                                                 NaN
# box_office                                             NaN
# ...

# %% [markdown]
# Значение `puNumber` в этой строке заменено на служебное `NaN` - нет данных.

# %%
mkrf_merge['puNumber'] = pd.to_numeric(mkrf_merge['puNumber'], errors='coerce')

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера</b>
#
# Отлично, что нашел дубликаты в этом столбце. Но что относительно типа данных?
#
# </div>
#
# ---
#
#
#
#
# <div class="alert alert-info">
# <b>изменил типы данных, объяснил почему это важно:</b>
# </div>

# %% [markdown]
# 2) `show_start_date` - переведем данные в тип данных 'дата' и отбросим время. Создадим столбцы `show_start_year` и `show_start_month`, `show_start_mnt_yr`(месяц+год выхода в прокат) для будущего анализа.

# %%
mkrf_merge['show_start_year'] = pd.to_datetime(mkrf_merge['show_start_date']).dt.tz_localize(None).dt.year
mkrf_merge['show_start_month'] = pd.to_datetime(mkrf_merge['show_start_date']).dt.tz_localize(None).dt. month
mkrf_merge['show_start_date'] = pd.to_datetime(mkrf_merge['show_start_date']).dt.tz_localize(None).dt.date
mkrf_merge['show_start_mnt_yr'] = mkrf_merge['show_start_date'].apply(lambda x: x.strftime('%B-%Y'))

# %% [markdown]
# Посмотрим на годы выхода фильмов и выделим наиболее популярный месяц для запуска фильма в прокат ниже.

# %%
mkrf_merge.groupby(mkrf_merge['show_start_year'])['puNumber'].count().plot(kind="bar",
                                                                    fontsize = 18,
                                                                    figsize=(16, 5),
                                                                    xlabel='год',
                                                                    ylabel='кол-во фильмов',
                                                                    title='Кол-во выхода в прокат фильмов по годам',
                                                                    rot = 45)
# Out:
# <AxesSubplot:title={'center':'Кол-во выхода в прокат фильмов по годам'}, xlabel='год', ylabel='кол-во фильмов'>

# %%
mkrf_merge_date_pivot_plot = pd.pivot_table(mkrf_merge,
                                            values='puNumber',
                                            index='show_start_year',
                                            columns='show_start_month',
                                            aggfunc=lambda x: len(x.unique()))


mkrf_merge_date_pivot_plot = mkrf_merge_date_pivot_plot.sort_index(ascending=False)

sns.set(rc={'figure.figsize':(16,8)})
ax = sns.heatmap(mkrf_merge_date_pivot_plot,
                 annot=True,
                 fmt=".0f",
                 linewidths=.5,
                 cmap="YlGnBu",
                 xticklabels=2,
                 yticklabels=2)

# %% [markdown]
# В нашей таблице содержатся фильмы вышедшие с 2010 по 2019 год. Как видно из матрицы выше, фильмы чаще выходят в декабре, однако картина может меняеться по годам.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера</b>
#
# Тут было бы неплохо охарактеризовать временной период данных полученных данных.
# </div>

# %% [markdown]
# 3) Для убедимся в сопоставимости и качестве значений для признаков `type`, `age_restriction`, `financing_source` — эти столбцы содержат довольно мало уникальных значенией - фактически это сведения о категориях, структурирем где это необходимо.

# %%
mkrf_merge['type'] = mkrf_merge['type'].str.lstrip()
mkrf_merge['type'] = mkrf_merge['type'].str.rstrip()
mkrf_merge['type'].value_counts()
# Out:
# Художественный                5909
# Анимационный                   829
# Прочие                         406
# Документальный                 288
# Научно-популярный               53
# Музыкально-развлекательный       1
# Name: type, dtype: int64

# %% [markdown]
# "Художественные" фильмы составляют большую часть выборки. Любопытное значение "прочие", если посмотрим на жанры фильмов этой категори увидем очень много документальных фильмов. Напоминаю, что у нас слишком большое кол-во возможных значений указания `genres` - cтоит провести проверку заполненеия признаков типа и жанра картин [позже](#basic_task_0).

# %%
mkrf_merge[mkrf_merge['type'] == 'Прочие']['genres'].value_counts().head(20)
# Out:
# документальный                         43
# документальный,биография               15
# документальный,музыка                  12
# концерт,музыка                          9
# драма                                   8
# документальный,биография,музыка         7
# документальный,история                  4
# комедия                                 4
# документальный,приключения              4
# мелодрама,музыка                        4
# документальный,короткометражка          4
# документальный,мюзикл                   4
# мультфильм,комедия,приключения          3
# ужасы                                   3
# мультфильм,фантастика,фэнтези           3
# музыка,концерт                          3
# концерт,музыка,документальный           3
# документальный,биография,история        2
# семейный,приключения,документальный     2
# документальный,музыка,концерт           2
# Name: genres, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера</b>
#
# Здорово, что оптимизировал названия жанра.
#
# </div>

# %% [markdown]
# Создадим числовой признак `age_limit`, на базе строкового `age_restriction`.

# %%
mkrf_merge['age_limit'] = mkrf_merge['age_restriction'].str[1:3]
mkrf_merge['age_limit'] = mkrf_merge['age_limit'].str.replace('\+','')
mkrf_merge['age_limit'] = pd.to_numeric(mkrf_merge['age_limit'], errors='coerce')
mkrf_merge['age_limit'].value_counts()
# Out:
# <ipython-input-21-07b1a411886b>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   mkrf_merge['age_limit'] = mkrf_merge['age_limit'].str.replace('\+','')
# 16    2851
# 18    1605
# 12    1593
# 0      811
# 6      626
# Name: age_limit, dtype: int64

# %% [markdown]
# Сведения об источнике финансирования указаны мало где, но заполнение выглядят вполне адекватно.

# %%
mkrf_merge['financing_source'].value_counts()
# Out:
# Министерство культуры               164
# Фонд кино                           146
# Министерство культуры, Фонд кино     22
# Name: financing_source, dtype: int64

# %% [markdown]
# 4) Посмотрим на значения в `ratings`. Обнаружено, что для **29 фильмов** рейтинг указан в процентах - изучив эти фильмы на сайте КиноПоиска - обнаружить какую-то логику не получилось. Создадим для этих фильмов отдельный набор (`mkrf_no_rating_backup`) и позже пример решение, как работать с этими данными.

# %%
mkrf_no_rating_backup = mkrf_merge[(~mkrf_merge['ratings'].isna()) \
           & (mkrf_merge['ratings'].str.contains('%'))]
mkrf_no_rating_backup.shape
# Out:
# (29, 20)

# %% [markdown]
# Трансфоримруем данные о рейтингах в числовой формат и посмотрим на разброс оценок по годам - увидем что значения рейтингов +/- одинаковы для каждого года выхода фильма. Любопытно посмотреть на фильмы с рейтингом меньше 4-х - изучем это подробнее позднее.

# %%
mkrf_merge['ratings'] = pd.to_numeric(mkrf_merge['ratings'], errors='coerce')

# %%
sns.set(rc={'figure.figsize':(16,10)})
ax = sns.boxplot(x="show_start_year", y="ratings",# hue="type",
                 data=mkrf_merge, linewidth=2.5)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера</b>
#
# Хорошо, что мы поймали эти проблемы с рейтингом. Действительно не ясно, что означают эти проценты.
# </div>

# %% [markdown]
# Сейчас мы не будем подробно изучать наборы данных, просто приведем к числовым значениям (по аналогии с рейтингами) показатели в столбцах:
#
# * 'refundable_support',
# * 'nonrefundable_support',
# * 'budget',
# * 'box_office'

# %%
for col in ['refundable_support',
 'nonrefundable_support',
 'budget',
 'box_office']:
    mkrf_merge[col] = pd.to_numeric(mkrf_merge[col], errors='coerce')

# %%
mkrf_merge.columns.tolist()
# Out:
# ['puNumber',
#  'show_start_date',
#  'ratings',
#  'type',
#  'genres',
#  'age_restriction',
#  'title',
#  'film_studio',
#  'production_country',
#  'director',
#  'producer',
#  'financing_source',
#  'refundable_support',
#  'nonrefundable_support',
#  'budget',
#  'box_office',
#  'show_start_year',
#  'show_start_month',
#  'show_start_mnt_yr',
#  'age_limit']

# %% [markdown]
# 5) `title` - кроме самого названия может содержать описание, год и альтернативное название. Нам важно использовать название фильма в дальнейшем для обогащения набор данных, поэтому выполним следующий набор действий:
#
# * избавимся от описания, которое соответствует шаблону `/По роману/повести/рассказу....`
# * избавимся от текста, который соответствует шаблону `4 цифы в скобках`
#
# отправим эти данные в отдельные признаки `notation`, оставшуюся часть назавния поместим в столбец `true_title`
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера</b>
#
# Немного не ясно, каким образом мы об этом узнали. Хорошо бы сначала вывести результаты по этим данным, а потом уже на основании фактов предложить основные проблемы. Дополнительно не ясна ситуация со слешем - в некоторых названиях это может быть не разделитель данных, а "фишка" названия. Это хорошо видно на примере ниже: фильмы `9/11`, `З/Л/О` и другие. Информация в скобках тоже может быть часть названия фильма. Поэтому, мне кажется, что лучше не нарушать целостность этих данных. Можно проверить по номеру удостоверения - действительно ли так зарегистрировано название. Если да, то тут ничего не поделать.
# </div>
#
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера</b>
#
# Тоже самое по году в названии - абсолютно не факт, что это год выхода фильма.</div>
#
# ---
#
#
#
#
# <div class="alert alert-info">
# <b>вывел подробнее информацию о названиях, определил в чем важность признака в описании:</b>
# </div>

# %%
mkrf_merge['notation'] = mkrf_merge['title'].str.extract(r'(\/По\s.+)')
mkrf_merge['title_true'] = mkrf_merge['title'].str.replace(r'(\/По\s.+)','')
mkrf_merge[mkrf_merge['title'].str.contains(r'(\/По\s.+)')]['title'].sample(10)
# Out:
# <ipython-input-28-19576c201858>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   mkrf_merge['title_true'] = mkrf_merge['title'].str.replace(r'(\/По\s.+)','')
# <ipython-input-28-19576c201858>:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   mkrf_merge[mkrf_merge['title'].str.contains(r'(\/По\s.+)')]['title'].sample(10)
# 2228    Рихард Штраус. Саломея /По одноименной драме О...
# 1713                  Телекинез /По роману Стивена Кинга/
# 356                   Дорога /По новелле Кормака МкКарфи/
# 4024    Развод по-фински (Дом, где растет любовь) /По ...
# 1934              Легкие деньги /По роману Маркуса Сэйки/
# 4194    Загадочная история Бенджамина Баттона /По расс...
# 4502    Чернильное сердце /По произведению Корнелии Фу...
# 4302        Ешь, молись, люби /По книге Элизабет Гилберт/
# 4659    P.S. Я люблю тебя /По одноименному произведени...
# ...

# %%
mkrf_merge['title_true'] = mkrf_merge['title_true'].str.replace(r'\(\d\d\d\d\)','')
mkrf_merge[mkrf_merge['title'].str.contains(r'\(\d\d\d\d\)')]['title'].sample(10).T
# Out:
# <ipython-input-29-c4f4750127a8>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   mkrf_merge['title_true'] = mkrf_merge['title_true'].str.replace(r'\(\d\d\d\d\)','')
# 3131                   Кукла (2016)
# 3471    Красавица и Чудовище (2017)
# 3725          Танцуй со мной (2015)
# 2760                 Мустанг (2015)
# 2970            Млечный путь (2015)
# 3740              Белые ночи (2017)
# 3045           Одноклассницы (2016)
# 3171                Выживший (2015)
# 2863                    Клан (2015)
# 3180                  Сёстры (2015)
# Name: title, dtype: object

# %%
mkrf_merge['title_true'] = mkrf_merge['title_true'].str.lstrip()
mkrf_merge['title_true'] = mkrf_merge['title_true'].str.rstrip()
mkrf_merge['title_true'] = mkrf_merge['title_true'].str.rstrip('_')
mkrf_merge[~mkrf_merge['notation'].isna()][['title',
                                            'show_start_date',
                                            'title_true',
                                           'notation']].sample(10)
# Out:
#                                                   title show_start_date  \
# 4193  Гарри Поттер и философский камень /По роману Д...      2010-11-30
# 1554  Жан-Мадлен Шнайцхеффер. Сильфида /По фантастич...      2013-09-23
# 682   Приключения Гекльберри Финна /По мотивам произ...      2013-04-25
# 387   Приключения Тинтина: Тайна Единорога /По серии...      2012-02-14
# 178            Заколдованная Элла /По книге Г.Г.Ливайн/      2014-10-15
# 5352  Лара Крофт - расхитительница гробниц: Колыбель...      2010-10-12
# 2077             Унижение /По произведению Филипа Рота/      2015-01-29
# 109   Гарри Поттер и орден Феникса /По роману Дж.К.Р...      2016-02-09
# 1322    Как я теперь люблю /По произведению Мэг Розофф/      2013-12-27
# 747   Груффало /По мотивам книги Джулии Дональдсон и...      2013-05-21
#
#                                              title_true  \
# 4193                  Гарри Поттер и философский камень
# 1554                   Жан-Мадлен Шнайцхеффер. Сильфида
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера</b>
#
# Мне кажется, что эти действия на этом этапе лишние. Мы как-то будем использовать эти данные в дальнейшем - если нет, то тогда лучше отказаться от этого. Тем более, что действительно, предложенная стратегия выделения названия не работает должным образом (это хорошо видно в результатах ниже).
#
# Нам лучше стараться оставить в тетрадке только те действия, которые направлены на решения поставленных задач. Нам надо стараться оптимизировать наши действия в анализе данных и направить все силы на достижения главной цели анализа данных.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера</b>
#
# Отлично, данные получили корректные типы.
# </div>

# %% [markdown]
# 6) Обратим внимание, что над фильмом могут работать большие коллективы: несколько студий, стран, режисеров и продюссеров.
#
# В столбцах идет перечисление через запятую, но в случае со странами, запятую иногда заменяют тире.

# %%
mkrf_merge[['film_studio', 'production_country', 'director', 'producer']].sample(20)
# Out:
#                                             film_studio  \
# 1027  Юниверсал Пикчерз, Борн Фильм Продакшнз, Кепти...
# 3321                           ООО "Пиманов и партнеры"
# 4577                                   Шанхай Кид Филмз
# 5218  Аймакс Корпорейшн, Локхид Мартин, НАСА, Аймакс...
# 5755                 ООО "Студия игрового кино "Краски"
# 2680                    ООО "Творческое объединение ЮГ"
# 1098  Ле Фильм дю Лендмен, Синемажинер, Майя Синема,...
# 5910                         ООО "Компания "Новые люди"
# 4435  ВестЭнд Филмз, Би-Би-Си Филмз, Руби Филмз Прод...
# 2697   Клиника Эстетико, Лстар Кэпитал, ТриСтар Пикчерз
# 3357                                    ООО "КиноФирма"
# 2055                              Киностудия "Мосфильм"
# 4044      НО "Фонд поддержки анимационного кино "Пилот"
# 201                               Киностудия "Мосфильм"
# 7036  Мираж Адвентюр, Саша Клайн Продакшн, Кинотур К...
# 3342                                              Трамп
# ...

# %% [markdown]
# Весьма вероятно, что это важный фактор при оценке сложности работы над фильмом. Произведем подсчет участников для каждого фильма в признаках:
# * 'film_studio',
# * 'production_country',
# * 'director',
# * 'producer'
# * так же подсчитаем кол-во указанных жанров

# %%
for col in ['film_studio', 'production_country', 'director', 'producer', 'genres']:
    mkrf_merge[f'counts_'+col] = mkrf_merge[col].str.count(',') + 1
        
mkrf_merge[f'counts_production_country'] += mkrf_merge['production_country'].str.count('-')

# %%
mkrf_merge.describe(include='all').iloc[:,-5:].T
# Out:
#                             count  unique  top  freq      mean       std  min  \
# counts_film_studio         7468.0     NaN  NaN   NaN  2.836502  2.419768  1.0
# counts_production_country  7484.0     NaN  NaN   NaN  1.367183  0.855837  1.0
# counts_director            7477.0     NaN  NaN   NaN  1.232981  0.954149  1.0
# counts_producer            6918.0     NaN  NaN   NaN  2.434663  1.451743  1.0
# counts_genres              6510.0     NaN  NaN   NaN  2.338556  0.770462  1.0
#
#                            25%  50%  75%   max
# counts_film_studio         1.0  2.0  4.0  17.0
# counts_production_country  1.0  1.0  1.0  10.0
# counts_director            1.0  1.0  1.0  18.0
# counts_producer            1.0  2.0  3.0  15.0
# counts_genres              2.0  3.0  3.0   3.0

# %% [markdown]
# В таблице выше мы видим, что для фильмов в нашей выборке наиболее распространена ситуция, когда у фильма:
#
# * 2 (чаще 3) студии участвовали в кинопроизводстве,
#
# * 2 (чаще 3) продюссера участвовали в кинопроизводстве,
#
# * больше чем половина фильмов характеризуется трехсоставным жанром.
#
# А так же видим:
#
# * до 10 стран могу участвовать в кинопроизводстве,
# * до 18 режисеров могу участвовать в кинопроизводстве,
# * до 15 режисеров могу участвовать в кинопроизводстве.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера</b>
#
# Да, интересные получаются результаты. Можно предположить, что существует положительная корреляция между числом продюсеров  и количеством стран, принимавших участие в создании фильма.</div>

# %%
# make new columns order and backup
w_df = mkrf_merge[['puNumber',
'show_start_year',
'age_limit',
'title_true',    
'title',
'ratings',

'type',
'genres',
'counts_genres',

'counts_director',
'director',

'counts_producer',
'producer',

'counts_film_studio',
'film_studio',

'counts_production_country',
'production_country',

'financing_source',
'refundable_support',
'nonrefundable_support',
'budget',
'box_office',

'show_start_date',
'show_start_month'
]].copy()

# %% [markdown]
# Кратко подведем итоги работы проделанной в данном блоке:
#
# 1) объединили 2 источника данных,
#
# 2) трансформировали типы данных в соответствии с логикой названия признаков, привели к числовым значениям по-максимум,
#
# 3) на основе существующих признаков сформировали более простые/понятные,
#
# 4) обозначили проблему дубликатов и малого кол-ва значений в некоторых признаках,
#
# 5) обозначили проблему необходимости более точной класиификации фильмов по типу и жанру и производителям.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера</b>
#
# Комментарий по оформлению тетрадки: лучше каждую логическую часть проекта заканчивать небольшим выводом о проделанных действиях с данными. Тем более, что на этом этапе было получено много интересных выводов. Добавь, пожалуйста, краткое обсуждение результатов с учетом основных задач проекта. Например, мы установили, что количество продюсеров и стран участников сильно варьирует, это надо учитывать при подсчете рейтинга продюсеров и тп.
#
# </div>

# %% [markdown]
# ## 2. Базовый ряд исследований предоставленных данных
#
# ### Качество исходных данных. Дубликаты и пропуски, их природа и решения по обогащению набора данных.
# <a class="anchor" id="basic_task_0"></a>
#
# [<назад](#dive_in) | [оглавление](#contents) | [дальше>](#basic_task_1)
#
# Еще раз взглянем на объем объем  отсутствующих данных:

# %%
show_percent_dict = {}

for _ in w_df.columns.tolist():
    percent = (w_df[w_df[_].isna()].shape[0] / w_df.shape[0]) * 100
    show_percent_dict[_] = percent

show_percent_dict = dict(sorted(show_percent_dict.items(), key=lambda x: x[1], reverse=True))
    
print(f'Всего строк в наборе данных: {w_df.shape[0]}\n')

for k,v in show_percent_dict.items():  
    v = str(int(v)) + '%'
    print(f'{v} - доля пропусков в столбце {k}')
# Out:
# Всего строк в наборе данных: 7486
#
# 95% - доля пропусков в столбце financing_source
# 95% - доля пропусков в столбце refundable_support
# 95% - доля пропусков в столбце nonrefundable_support
# 95% - доля пропусков в столбце budget
# 57% - доля пропусков в столбце box_office
# 13% - доля пропусков в столбце ratings
# 13% - доля пропусков в столбце genres
# 13% - доля пропусков в столбце counts_genres
# 7% - доля пропусков в столбце counts_producer
# 7% - доля пропусков в столбце producer
# 0% - доля пропусков в столбце counts_film_studio
# 0% - доля пропусков в столбце film_studio
# 0% - доля пропусков в столбце counts_director
# 0% - доля пропусков в столбце director
# 0% - доля пропусков в столбце counts_production_country
# 0% - доля пропусков в столбце production_country
# 0% - доля пропусков в столбце puNumber
# 0% - доля пропусков в столбце show_start_year
# 0% - доля пропусков в столбце age_limit
# 0% - доля пропусков в столбце title_true
# ...

# %% [markdown]
# <div class="alert alert-danger">
# Нам лучше как-то систематизировать работу с пропусками в этом блоке. Сперва можно подсчитать процент пропусков для каждого столбца. Затем рассмотреть – есть ли какие-то закономерности в пропусках? После этого мы можем уже более детально посмотреть на пропуски и предложить, что с ними делать (как их обрабатывать). Например, была отличная идея использовать внешние базы данных для заполнения пропусков в столбце жанры. Тогда эту идею нужно реализовать в этом блоке.
#
# В заключении нам следует сделать небольшой вывод, где указать, что было и как стало. Пожалуйста, дополни эту часть проекта.
# </div>

# %% [markdown]
# В целом на данный момент объем данных довольно мал, качественное исследование требует больше информации -ниже рассмотрим варианты расширения выборки за счет внешних источников - открытых данных МКРФ о кинопроизводстве.
#
# 1) [Реестр прокатных удостоверений фильмов](https://opendata.mkrf.ru/opendata/7705851331-register_movies)
#
# 2) [Данные о кассовых сборах](https://opendata.mkrf.ru/opendata/7705851331-movie_gross)
#
# 3) [Данные о гос. инвестировании](https://ekinobilet.fond-kino.ru/government-support/)
#
# Главная задача - нужно существенно расширить данны о бюджетах (сейчас доступны данные для 332 картин) и прокатных сборах фильмов, препятствием может стать 1000 (чуть меньше) дублей по названию фильмов.
#
#
# Изучим данные по порядку, загрузим общедоступный реестр прокатных удостоверений:

# %%
mkrf_true_pNum = pd.read_csv('C:\\Users\\KorneevSN\\Downloads\\КНИГИ\\y.praktice\\data-7-structure-4.csv')
mkrf_true_pNum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93927 entries, 0 to 93926
# Data columns (total 48 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Название фильма                                        93927 non-null  object
#  1   Hаименование на иностранном языке                      48530 non-null  object
#  2   Номер удостоверения                                    93927 non-null  object
#  3   Дата регистрации удостоверения                         93925 non-null  object
#  4   Дата начала показа фильма                              93622 non-null  object
#  5   Примечание                                             29185 non-null  object
#  6   Идентификатор записи реестра                           93927 non-null  int64
#  7   Аннотация                                              88138 non-null  object
# ...

# %%
len(mkrf_true_pNum['Название фильма'].unique())
# Out:
# 77832

# %% [markdown]
# Мы получили гораздо больше данных, о `77 832` уникальных наименованиях фильмов.
#
# Проверим, сопоставляются ли номера прокатных удостоверений в наших исходных данных с данными получеными из свободного источника:

# %%
mkrf_true_pNum['Номер удостоверения'] = pd.to_numeric(mkrf_true_pNum['Номер удостоверения'], errors='coerce')

current_pnum = set(w_df['puNumber'].tolist())
true_pnum = set(mkrf_true_pNum['Номер удостоверения'].tolist())

print(f'{len(set(current_pnum) & set(true_pnum))} номеров прокатного удостоверенеия есть в обеих таблицах.')
# Out:
# 7483 номеров прокатного удостоверенеия есть в обеих таблицах.

# %% [markdown]
# Напомню, в исходных данных у нас есть две пары дублей, а так же одна из картин не имеет номера прокатного удостоверения - таким образом все 7483 прокатных удостоврения присутствуют в обеих таблицах. Рассмотрим эти кейсы со странными прокатными номерами:

# %%
w_df[w_df['puNumber'].isna()]
# Out:
#       puNumber  show_start_year  age_limit                         title_true  \
# 1797       NaN             2014         12  Курбан-роман. (История с жертвой)
#
#                                   title  ratings            type genres  \
# 1797  Курбан-роман. (История с жертвой)      NaN  Художественный    NaN
#
#       counts_genres  counts_director director  counts_producer    producer  \
# 1797            NaN              1.0  С.Юзеев              1.0  М.Галицкая
#
#       counts_film_studio       film_studio  counts_production_country  \
# 1797                 1.0  ФОНД "ИННОВАЦИЯ"                        1.0
#
#      production_country financing_source  refundable_support  \
# 1797             Россия              NaN                 NaN
#
#       nonrefundable_support  budget  box_office show_start_date  \
# 1797                    NaN     NaN         NaN      2014-05-15
#
#       show_start_month
# 1797                 5

# %% [markdown]
# Изменим наименование признаков в новой таблице в соответствии с исходником

# %%
mkrf_true_pNum = mkrf_true_pNum[['Название фильма',
                                 'Hаименование на иностранном языке',
                                 'Номер удостоверения',
                                 'Дата регистрации удостоверения', 'Дата начала показа фильма', 'Примечание',
                                 'Идентификатор записи реестра', 'Аннотация', 'Вид Фильма', 'Категория',
                                 'Язык оригинала', 'Формат кадра', 'Количество серий',
                                 'Метраж (для фильмов на кинопленке)',
                                 'Количество частей/рулонов (для фильмов на кинопленке)',
                                 'Цвет', 'Продолжительность демонстрации, часы',
                                 'Продолжительность демонстрации, минуты', 'Формат носителя',
                                 'Объем носителя', 'Единица измерения', 'Студия-производитель', 'Страна производства',
                                 'Год производства', 'Режиссер', 'Художник', 'Сценарист',
                                 'Оператор', 'Композитор',
                                 'Продюсер', 'Права на использование фильма', 'Категория прав на использование фильма',
                                 'Срок действия прав на использование фильма',
                                 'Срок действия прав на способ использования фильма',
                                 'Возрастная категория', 'Возрастная категория.1', 'Дубляж (где дублирован)',
                                 'Срок действия прав проката до',
                                 'Код', 'Права проката переданы', 'Порядковый номер переоформления/продления',
                                 'Должность подписанта',
                                 'ФИО подписанта', 'Запись удалена', 'Дата удаления записи',
                                 'Не показывать на сайте mkrf.ru', 'дата создания объекта', 'дата обновления объекта']]


New_Labels = ['title',
                                 'title_foreign',
                                 'mkrf_pNum',
                                 'Дата регистрации удостоверения', 'show_start_date', 'description',
                                 'Идентификатор записи реестра', 'annot', 'type', 'film_cat',
                                 'lang', 'Формат кадра', 'count_series',
                                 'Метраж (для фильмов на кинопленке)',
                                 'Количество частей/рулонов (для фильмов на кинопленке)',
                                 'color', 'film_h_lenght',
                                 'film_m_lenght', 'Формат носителя',
                                 'Объем носителя', 'Единица измерения', 'film_studio', 'production_country',
                                 'prod_year', 'director', 'painter', 'screenwriter',
                                 'operator', 'composer',
                                 'producer', 'Права на использование фильма', 'Категория прав на использование фильма',
                                 'Срок действия прав на использование фильма',
                                 'Срок действия прав на способ использования фильма',
                                 'age_limit', 'age_limit_second', 'Дубляж (где дублирован)',
                                 'Срок действия прав проката до',
                                 'Код', 'Права проката переданы', 'Порядковый номер переоформления/продления',
                                 'Должность подписанта',
                                 'ФИО подписанта', 'Запись удалена', 'Дата удаления записи',
                                 'Не показывать на сайте mkrf.ru', 'дата создания объекта', 'дата обновления объекта']





mkrf_true_pNum.columns = New_Labels

# %% [markdown]
# Вывыедем информацию о фильме `Курбан-роман` из обеих таблиц:

# %%
pd.concat([w_df[w_df['title'].str.contains('Курбан-роман')][['puNumber',
                                                            'show_start_date',
                                                             'age_limit',
                                                             'genres',
                                                             'ratings',
                                                            'title',
                                                            'director',
                                                            'producer',
                                                            'film_studio',
                                                            'production_country',
                                                            'budget',
                                                            'box_office']],
mkrf_true_pNum[mkrf_true_pNum['title'].str.contains('Курбан-роман')][['mkrf_pNum',
                                                            'show_start_date',
                                                            'age_limit','type',
                                                            'title',
                                                            'director',
                                                            'producer',
                                                            'film_studio',
                                                            'production_country']]],
ignore_index=True)
# Out:
#       puNumber           show_start_date                      age_limit  \
# 0          NaN                2014-05-15                             12
# 1  111009614.0                2014-09-02                             12
# 2          NaN  2014-05-15T12:00:00.000Z  «12+» для детей старше 12 лет
# 3          NaN  2014-09-02T12:00:00.000Z  «12+» для детей старше 12 лет
#
#   genres  ratings                               title director    producer  \
# 0    NaN      NaN   Курбан-роман. (История с жертвой)  С.Юзеев  М.Галицкая
# 1    NaN      NaN  Курбан-роман. (История с жертвой).  С.Юзеев  М.Галицкая
# 2    NaN      NaN   Курбан-роман. (История с жертвой)  С.Юзеев  М.Галицкая
# 3    NaN      NaN  Курбан-роман. (История с жертвой).  С.Юзеев  М.Галицкая
#
#         film_studio production_country  budget  box_office    mkrf_pNum  \
# 0  ФОНД "ИННОВАЦИЯ"             Россия     NaN         NaN          NaN
# 1  ФОНД "ИННОВАЦИЯ"             Россия     NaN         0.0          NaN
# ...

# %% [markdown]
# Видим, что строки по фильмам похожи, и не содержат большой разницы -можем избавимся от запсии без номера прокатного удостоврения. Далее посмотрим на строки с дублями по номеру `прокатного уудостоверения`.

# %%
w_df[w_df.duplicated(subset='puNumber',keep='first')]
# Out:
#          puNumber  show_start_year  age_limit  \
# 4639  221154310.0             2010         16
# 5068  221054410.0             2010         12
#
#                                 title_true  \
# 4639  Иоанна - женщина на папском престоле
# 5068                        Анализируй то!
#
#                                                   title  ratings  \
# 4639  Иоанна - женщина на папском престоле /По роман...      7.6
# 5068                                     Анализируй то!      6.8
#
#                 type                   genres  counts_genres  counts_director  \
# 4639  Художественный  драма,мелодрама,история            3.0              1.0
# 5068  Художественный         комедия,криминал            2.0              1.0
#
#             director  counts_producer  \
# 4639  Зенке Вортманн              3.0
# 5068  Гарольд Реймис              2.0
#
#                                         producer  counts_film_studio  \
# ...

# %%
pNum_for_check = [221154310.0, 221054410.0]
pd.concat([w_df[w_df['puNumber'].isin(pNum_for_check)][['puNumber',
                                                            'show_start_date',
                                                             'age_limit',
                                                             'genres',
                                                             'ratings',
                                                            'title',
                                                            'director',
                                                            'producer',
                                                            'film_studio',
                                                            'production_country',
                                                            'budget',
                                                            'box_office']],
mkrf_true_pNum[mkrf_true_pNum['mkrf_pNum'].isin(pNum_for_check)][['mkrf_pNum',
                                                            'show_start_date',
                                                            'age_limit','type',
                                                            'title',
                                                            'director',
                                                            'producer',
                                                            'film_studio',
                                                            'production_country']]],
ignore_index=True).T
# Out:
#                                                                     0  \
# puNumber                                                  221154310.0
# show_start_date                                            2010-12-17
# age_limit                                                          16
# genres                                              мелодрама,комедия
# ratings                                                           7.0
# title                                Как жениться и остаться холостым
# director                                                 Эрик Лартиго
# producer                                      Амандин Било, Алан Шаба
# film_studio         Ше Вам, Скрипт Ассосье, Тэ Фэ 1 Фильм Продюксь...
# production_country                                            Франция
# budget                                                            NaN
# box_office                                                        NaN
# ...

# %% [markdown]
# Проверим кол-во дублей в таблице `mkrf_pNum`:

# %%
mkrf_true_pNum[mkrf_true_pNum['mkrf_pNum'].duplicated(keep='first')].shape
# Out:
# (1912, 48)

# %% [markdown]
# Видим, что данная ошибка содержится в обеих таблицах. Так же ясно, что таблицы хорошо сопоставимы, мы можем обогатить таблицу `mkrf_true_pNum` исходными данными и продолжить работу с большим количеством фильмов. Убедимся, что в `mkrf_true_pNum` содержится достаточное количество фильмов выпущеных в период 2010-2019 годов.

# %%
mkrf_true_pNum_with_show_start_date = mkrf_true_pNum[~mkrf_true_pNum['show_start_date'].isna()]

# %%
mkrf_true_pNum_with_show_start_date['show_start_year'] = pd.to_datetime(mkrf_true_pNum_with_show_start_date['show_start_date']).dt.tz_localize(None).dt.year
mkrf_true_pNum_with_show_start_date['show_start_month'] = pd.to_datetime(mkrf_true_pNum_with_show_start_date['show_start_date']).dt.tz_localize(None).dt. month
mkrf_true_pNum_with_show_start_date['show_start_date'] = pd.to_datetime(mkrf_true_pNum_with_show_start_date['show_start_date']).dt.tz_localize(None).dt.date
# Out:
# <ipython-input-114-2e854cb0df92>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mkrf_true_pNum_with_show_start_date['show_start_year'] = pd.to_datetime(mkrf_true_pNum_with_show_start_date['show_start_date']).dt.tz_localize(None).dt.year
# <ipython-input-114-2e854cb0df92>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mkrf_true_pNum_with_show_start_date['show_start_month'] = pd.to_datetime(mkrf_true_pNum_with_show_start_date['show_start_date']).dt.tz_localize(None).dt. month
# ...

# %%
mkrf_for_plot = mkrf_true_pNum_with_show_start_date[mkrf_true_pNum_with_show_start_date['show_start_year'] > 2000]
mkrf_for_plot.groupby(mkrf_for_plot['show_start_year'])['mkrf_pNum'].count().plot(kind="bar",
                                                                    fontsize = 18,
                                                                    figsize=(16, 5),
                                                                    xlabel='год',
                                                                    ylabel='кол-во фильмов',
                                                                    title='Кол-во выхода в прокат фильмов по годам',
                                                                    rot = 45)
# Out:
# <AxesSubplot:title={'center':'Кол-во выхода в прокат фильмов по годам'}, xlabel='год', ylabel='кол-во фильмов'>

# %% [markdown]
# Посмотрим на данные о кассовых сборах:

# %%
mkrf_true_box_office = pd.read_csv('data-5-structure-1.csv')
mkrf_true_box_office.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Название                626 non-null    object
#  1   № ПУ                    615 non-null    object
#  2   Сборы, руб.             626 non-null    float64
#  3   Тип                     626 non-null    object
#  4   Возрастное ограничение  626 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 24.6+ KB

# %%
mkrf_true_box_office.sample(7)
# Out:
#                        Название       № ПУ   Сборы, руб.             Тип  \
# 237    Клара и Волшебный дракон  124009019  7.899829e+06    анимационный
# 40   Кладбище домашних животных  124001819  3.736401e+08    анимационный
# 18          Алита: Боевой ангел  121000619  7.578647e+08  художественный
# 355                 Оленья кожа  121021819  2.595630e+06  художественный
# 242                Люби их всех  111007119  7.228656e+06  художественный
# 570             20:20. Альманах  226019519  2.046530e+05          другой
# 28         Angry birds 2 в кино  124005619  5.171166e+08    анимационный
#
#             Возрастное ограничение
# 237    «6+» для детей старше 6 лет
# 40       «18+» запрещено для детей
# 18   «16+» для детей старше 16 лет
# 355      «18+» запрещено для детей
# 242      «18+» запрещено для детей
# 570  «12+» для детей старше 12 лет
# 28     «6+» для детей старше 6 лет

# %% [markdown]
# Датасет довольно маленький, но видим, что в столбце `№ ПУ` идет перечисление прокатных удостоверений, посмотрим сколько всего прокатных удостоверений находится здесь и как они соотносятся с исходными данными:

# %%
mkrf_true_box_office.iloc[464,:]
# Out:
# Название                                        Русское краткое. Выпуск 2-6
# № ПУ                      111024718 / 111004219 / 111011419 / 111015019 ...
# Сборы, руб.                                                       1156482.0
# Тип                                                          художественный
# Возрастное ограничение    «16+» для детей старше 16 лет / «18+» запрещен...
# Name: 464, dtype: object

# %%
mkrf_true_box_office['count_pu'] = mkrf_true_box_office['№ ПУ'].str.count('/') + 1
mkrf_true_box_office['№ ПУ'] = mkrf_true_box_office['№ ПУ'].str.split(' / ')
mkrf_true_box_office = mkrf_true_box_office.explode('№ ПУ').drop_duplicates()
mkrf_true_box_office = mkrf_true_box_office.reset_index()
mkrf_true_box_office.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651 entries, 0 to 650
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   index                   651 non-null    int64
#  1   Название                651 non-null    object
#  2   № ПУ                    640 non-null    object
#  3   Сборы, руб.             651 non-null    float64
#  4   Тип                     651 non-null    object
#  5   Возрастное ограничение  651 non-null    object
#  6   count_pu                640 non-null    float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 35.7+ KB

# %%
mkrf_true_box_office['count_pu'].value_counts()
# Out:
# 1.0    603
# 2.0     16
# 8.0      8
# 4.0      8
# 5.0      5
# Name: count_pu, dtype: int64

# %%
mkrf_true_box_office[mkrf_true_box_office['Название'] == 'Русское краткое. Выпуск 2-6']
# Out:
#      index                     Название       № ПУ  Сборы, руб.  \
# 482    464  Русское краткое. Выпуск 2-6  111024718    1156482.0
# 483    464  Русское краткое. Выпуск 2-6  111004219    1156482.0
# 484    464  Русское краткое. Выпуск 2-6  111011419    1156482.0
# 485    464  Русское краткое. Выпуск 2-6  111015019    1156482.0
# 486    464  Русское краткое. Выпуск 2-6  111021018    1156482.0
#
#                 Тип                             Возрастное ограничение  \
# 482  художественный  «16+» для детей старше 16 лет / «18+» запрещен...
# 483  художественный  «16+» для детей старше 16 лет / «18+» запрещен...
# 484  художественный  «16+» для детей старше 16 лет / «18+» запрещен...
# 485  художественный  «16+» для детей старше 16 лет / «18+» запрещен...
# 486  художественный  «16+» для детей старше 16 лет / «18+» запрещен...
#
#      count_pu
# 482       5.0
# 483       5.0
# 484       5.0
# 485       5.0
# 486       5.0

# %% [markdown]
# Сверим сколько номеров прокатных удостоверений есть в исходной и новой таблице:

# %%
mkrf_true_box_office['№ ПУ'] = pd.to_numeric(mkrf_true_box_office['№ ПУ'], errors='coerce')

current_pnum = set(w_df['puNumber'].tolist())
check_pnum = set(mkrf_true_box_office['№ ПУ'].tolist())

print(f'{len(set(current_pnum) & set(check_pnum))} номеров прокатного удостоверенеия есть в обеих таблицах.')
# Out:
# 598 номеров прокатного удостоверенеия есть в обеих таблицах.

# %%
mkrf_merge_add_box = mkrf_merge.merge(mkrf_true_box_office[['Название',
                                                            '№ ПУ',
                                                            'Сборы, руб.',
                                                           'count_pu']], how='left',
                                      left_on='puNumber',
                                      right_on='№ ПУ').copy()

# %%
mkrf_merge_add_box['same_box_office'] = mkrf_merge_add_box['box_office'] == mkrf_merge_add_box['Сборы, руб.']
mkrf_merge_add_box['same_box_office'].value_counts()
# Out:
# False    6932
# True      564
# Name: same_box_office, dtype: int64

# %%
mkrf_merge_add_box[(mkrf_merge_add_box['same_box_office'] == False) &
                  (~mkrf_merge_add_box['box_office'].isna()) &
                  (~mkrf_merge_add_box['Сборы, руб.'].isna())].T
# Out:
#                                                                         5758  \
# puNumber                                                         111001418.0
# show_start_date                                                   2018-03-10
# ratings                                                                  NaN
# type                                                          Художественный
# genres                                                                   NaN
# age_restriction                       «0+» - для любой зрительской аудитории
# title                      Бегство рогатых викингов или пять дней из джиз...
# film_studio                                              Ассоциация НП "КОТ"
# production_country                                                    Россия
# director                                                       И.Белостоцкий
# producer                                                       И.Белостоцкий
# ...

# %%
print(f'{len(set(true_pnum) & set(check_pnum))} номеров прокатного удостоверенеия есть в обеих таблицах.')
# Out:
# 640 номеров прокатного удостоверенеия есть в обеих таблицах.

# %% [markdown]
# Можем немного обновить данные о прокатных сборах.

# %% [markdown]
# Далее рассмотрим данные о государственной поддержке фильмов доступные [на сайте ЕИАС](https://ekinobilet.fond-kino.ru/government-support/). Для этого сохраним код страницы в файл `index.html`, проведем парсинг открытых данных, и сформируем таблицу с результатом `parsed_data`, реализация ниже:

# %%
with open("index.html", encoding="utf-8") as file:
    src = file.read()

soup = BeautifulSoup(src, "lxml")

all_soup = soup.find_all("div", class_='r-table__row')

parse_financing_source_list = []
film_title_list = []
film_studio_list = []
release_date_list = []
refundable_support_list = []
nonrefundable_support_list = []
budget_list = []
box_office_list = []
audience_list = []

for items in all_soup[1:]:
    targets_in_item = items.find_all("div")
    
    try:  
        parse_financing_source = targets_in_item[0]
        parse_financing_source = str(parse_financing_source)
        parse_financing_source = re.findall(r'[А-Яа-я+]+\s[А-Яа-я+]+', parse_financing_source)
        parse_financing_source = ', '.join([str(elem) for elem in parse_financing_source])
        parse_financing_source_list.append(parse_financing_source)
    except: parse_financing_source_list.append('—')
    
    try:
        parse_film_title = targets_in_item[2]
        parse_film_title = parse_film_title.find("div",
                                                 class_="r-table__text r-table__project-name js-bitwise-digit")
        film_title_list.append(parse_film_title.text)
    except: film_title_list.append('—')

    try: 
        parse_film_studio = targets_in_item[5] 
        parse_film_studio = parse_film_studio.find("div",
                                                   class_="r-table__text js-bitwise-digit r-table__company expandable-item visible")
        film_studio_list.append(parse_film_studio.text)
    except: film_studio_list.append('—')
    try: 
        parse_release_date = targets_in_item[7] 
        parse_release_date = parse_release_date.find("div",
                                                   class_="r-table__text js-bitwise-digit")
        release_date_list.append(parse_release_date.text)
    except: release_date_list.append('—')
    try: 
        parse_refundable_support = targets_in_item[9] 
        parse_refundable_support = parse_refundable_support.find("div",
                                                   class_="r-table__text js-bitwise-digit")
        refundable_support_list.append(parse_refundable_support.text)
    except: refundable_support_list.append('—')
    try: 
        parse_nonrefundable_support = targets_in_item[11] 
        parse_nonrefundable_support = parse_nonrefundable_support.find("div",
                                                   class_="r-table__text js-bitwise-digit")
        nonrefundable_support_list.append(parse_nonrefundable_support.text)
    except: nonrefundable_support_list.append('—')
    try: 
        parse_budget = targets_in_item[15] 
        parse_budget = parse_budget.find("div",
                                                   class_="r-table__text js-bitwise-digit")
        budget_list.append(parse_budget.text)
    except: budget_list.append('—')
    try: 
        parse_box_office = targets_in_item[17] 
        parse_box_office = parse_box_office.find("div",
                                                   class_="r-table__text js-bitwise-digit")
        box_office_list.append(parse_box_office.text)
    except: box_office_list.append('—')
    try: 
        parse_audience = targets_in_item[19] 
        parse_audience = parse_audience.find("div",
                                                   class_="r-table__text js-bitwise-digit")
        audience_list.append(parse_audience.text)
    except: audience_list.append('—')
        
        
parsed_data = pd.DataFrame(
    {'financing_source': parse_financing_source_list,
     'title': film_title_list,
     'film_studio': film_studio_list,
          'release_date': release_date_list,
          'refundable_support': refundable_support_list,
          'nonrefundable_support': nonrefundable_support_list,
          'budget': budget_list,
          'box_office': box_office_list,
          'audience': audience_list})


for _ in parsed_data.columns.tolist()[4:]:
    parsed_data[_] = parsed_data[_].str.replace(' ','')
    parsed_data[_] = parsed_data[_].str.replace('-','0')
    parsed_data[_] = pd.to_numeric(parsed_data[_], errors='coerce')
    
parsed_data['release_date'] = pd.to_datetime(parsed_data['release_date'], format='%d.%m.%Y', errors='coerce')

# %%
parsed_data.describe(include='all').T
# Out:
# <ipython-input-123-0507ec54962b>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   parsed_data.describe(include='all').T
#                        count unique                               top freq  \
# financing_source         435      3             Министерство культуры  218
# title                    435    434  Затмение (Битва с экстрасенсами)    2
# film_studio              435    216           ООО "КИНОКОМПАНИЯ "СТВ"   24
# release_date             424    267               2016-10-27 00:00:00    5
# refundable_support     426.0    NaN                               NaN  NaN
# nonrefundable_support  426.0    NaN                               NaN  NaN
# budget                 405.0    NaN                               NaN  NaN
# ...

# %% [markdown]
# Прекрасно, мы получили еще немного данных о госсударственной поддержке и бюджетах. Теперь объединим эту информацию.

# %%
mkrf_true_pNum.columns.tolist()
# Out:
# ['title',
#  'title_foreign',
#  'mkrf_pNum',
#  'Дата регистрации удостоверения',
#  'show_start_date',
#  'description',
#  'Идентификатор записи реестра',
#  'annot',
#  'type',
#  'film_cat',
#  'lang',
#  'Формат кадра',
#  'count_series',
#  'Метраж (для фильмов на кинопленке)',
#  'Количество частей/рулонов (для фильмов на кинопленке)',
#  'color',
#  'film_h_lenght',
#  'film_m_lenght',
#  'Формат носителя',
#  'Объем носителя',
#  'Единица измерения',
#  'film_studio',
#  'production_country',
#  'prod_year',
#  'director',
#  'painter',
#  'screenwriter',
#  'operator',
#  'composer',
#  'producer',
#  'Права на использование фильма',
#  'Категория прав на использование фильма',
#  'Срок действия прав на использование фильма',
#  'Срок действия прав на способ использования фильма',
#  'age_limit',
#  'age_limit_second',
#  'Дубляж (где дублирован)',
#  'Срок действия прав проката до',
#  'Код',
#  'Права проката переданы',
#  'Порядковый номер переоформления/продления',
# ...

# %%
mkrf_true_pNum_for_merge = mkrf_true_pNum[['title',
 'title_foreign',
 'mkrf_pNum',
 'show_start_date',
 'description',
 'annot',
 'type',
 'film_cat',
 'count_series',
 'color',
 'film_h_lenght',
 'film_m_lenght',
 'film_studio',
 'production_country',
 'prod_year',
 'director',
 'painter',
 'screenwriter',
 'operator',
 'composer',
 'producer',
 'age_limit',
 'age_limit_second']]

# %%
mkrf_global_merge = mkrf_true_pNum_for_merge.merge(mkrf_merge, how='left',
                                      left_on='mkrf_pNum',
                                      right_on='puNumber').copy()


mkrf_global_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93931 entries, 0 to 93930
# Data columns (total 50 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   title_x                    93931 non-null  object
#  1   title_foreign              48534 non-null  object
#  2   mkrf_pNum                  92117 non-null  float64
#  3   show_start_date_x          93626 non-null  object
#  4   description                29185 non-null  object
#  5   annot                      88142 non-null  object
#  6   type_x                     93926 non-null  object
#  7   film_cat                   93931 non-null  object
#  8   count_series               36316 non-null  float64
#  9   color                      93925 non-null  object
#  10  film_h_lenght              77366 non-null  float64
#  11  film_m_lenght              91412 non-null  float64
#  12  film_studio_x              93807 non-null  object
# ...

# %%
mkrf_global_merge[mkrf_global_merge['title_y']]

# %% [markdown]
# 7. Решите проблемы с пропусками в данных с помощью внешних источников.
# 8. Сейчас наши коллеги-аналитики работают с данными в Экселе и тратят
# много времени на обработку. Данные проекта - результат из работы. Ваша
# задача указать проблемы в данных, которые они упустили. И показать
# преимущества pandas для подобных задач.

# %%
# https://github.com/miptgirl/kinopoisk_data.git

git_kinopois_df = pd.read_csv('kp_all_movies.csv')
git_kinopois_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36417 entries, 0 to 36416
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie_id           36417 non-null  int64
#  1   name_rus           36417 non-null  object
#  2   kp_rating          36416 non-null  float64
#  3   movie_duration     36417 non-null  object
#  4   kp_rating_count    36416 non-null  float64
#  5   movie_year         36417 non-null  int64
#  6   imdb_rating        33131 non-null  float64
#  7   imdb_rating_count  33131 non-null  float64
#  8   genres             36307 non-null  object
#  9   countries          36417 non-null  object
#  10  budget             11002 non-null  object
#  11  critics_rating     11564 non-null  float64
#  12  name_eng           29019 non-null  object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 3.6+ MB

# %%
git_kinopois_df[git_kinopois_df['kp_rating'] > 8].sample(6).T
# Out:
#                                                  25434              18386  \
# movie_id                                        615575              46592
# name_rus           Очень поттеровское продолжение (ТВ)            Медведь
# kp_rating                                        8.492              8.094
# movie_duration                                     213                 45
# kp_rating_count                                  394.0              762.0
# movie_year                                        2010               1938
# imdb_rating                                        8.6                7.8
# imdb_rating_count                               1037.0               81.0
# genres                               [мюзикл, комедия]  [мюзикл, комедия]
# countries                                        [США]             [СССР]
# budget                                             NaN                NaN
# critics_rating                                     NaN                NaN
# ...

# %%
git_kinopois_df.describe(include='all').T
# Out:
#                      count unique                                 top   freq  \
# movie_id           36417.0    NaN                                 NaN    NaN
# name_rus             36417  33952                              Ярость     10
# kp_rating          36416.0    NaN                                 NaN    NaN
# movie_duration       36417    419                                  90   1835
# kp_rating_count    36416.0    NaN                                 NaN    NaN
# movie_year         36417.0    NaN                                 NaN    NaN
# imdb_rating        33131.0    NaN                                 NaN    NaN
# imdb_rating_count  33131.0    NaN                                 NaN    NaN
# genres               36307   3001                             [драма]   3497
# countries            36417   2319                               [США]  12244
# budget               11002   1816                          $5 000 000    353
# ...

# %%
git_kinopois_df[git_kinopois_df['movie_year'] > 1997].groupby(git_kinopois_df['movie_year'])['movie_id'].count().plot(kind="bar",
                                                                    fontsize = 18,
                                                                    figsize=(16, 5),
                                                                    xlabel='год',
                                                                    ylabel='кол-во фильмов',
                                                                    title='Кол-во выхода в прокат фильмов по годам',
                                                                    rot = 45)
# Out:
# <AxesSubplot:title={'center':'Кол-во выхода в прокат фильмов по годам'}, xlabel='год', ylabel='кол-во фильмов'>

# %%
w_df_title_set = set(w_df['title'].tolist())
git_kinopois_df_title_set = set(git_kinopois_df['name_rus'].tolist())

print(f'{len(set(git_kinopois_df_title_set) & set(w_df_title_set))} номеров названий есть в обеих таблицах.')
# Out:
# 2250 номеров названий есть в обеих таблицах.

# %% [markdown]
# # Попробуем консолидировать все данные, посмотрим на заполненность признаков после этого.
#
# <a class="anchor" id="here"></a>
# [<назад](#basic_task_0) | [оглавление](#contents) | [дальше>](#basic_task_2)

# %%
df_list = [w_df,
mkrf_true_pNum,
mkrf_true_box_office,
parsed_data,
git_kinopois_df]

dict_df_structure = {}
for df in df_list:
    dict_df_structure['struct_'+str(df.shape[0])] = df.columns.tolist()
    
for k,v in dict_df_structure.items():
    print(k, '\n', v, '\n\n')
# Out:
# struct_7486
#  ['puNumber', 'show_start_year', 'show_start_month', 'age_limit', 'title_true', 'alter_title', 'title', 'type', 'genres', 'ratings', 'counts_film_studio', 'film_studio', 'counts_production_country', 'production_country', 'counts_director', 'director', 'counts_producer', 'producer', 'financing_source', 'refundable_support', 'nonrefundable_support', 'budget', 'box_office', 'show_start_date', 'show_start_mnt_yr', 'age_restriction']
#
#
# struct_93927
# ...

# %%
mkrf_true_pNum = mkrf_true_pNum[['Название фильма',
                                 'Hаименование на иностранном языке',
                                 'Номер удостоверения',
                                 'Дата регистрации удостоверения', 'Дата начала показа фильма', 'Примечание',
                                 'Идентификатор записи реестра', 'Аннотация', 'Вид Фильма', 'Категория',
                                 'Язык оригинала', 'Формат кадра', 'Количество серий',
                                 'Метраж (для фильмов на кинопленке)',
                                 'Количество частей/рулонов (для фильмов на кинопленке)',
                                 'Цвет', 'Продолжительность демонстрации, часы',
                                 'Продолжительность демонстрации, минуты', 'Формат носителя',
                                 'Объем носителя', 'Единица измерения', 'Студия-производитель', 'Страна производства',
                                 'Год производства', 'Режиссер', 'Художник', 'Сценарист',
                                 'Оператор', 'Композитор',
                                 'Продюсер', 'Права на использование фильма', 'Категория прав на использование фильма',
                                 'Срок действия прав на использование фильма',
                                 'Срок действия прав на способ использования фильма',
                                 'Возрастная категория', 'Возрастная категория.1', 'Дубляж (где дублирован)',
                                 'Срок действия прав проката до',
                                 'Код', 'Права проката переданы', 'Порядковый номер переоформления/продления',
                                 'Должность подписанта',
                                 'ФИО подписанта', 'Запись удалена', 'Дата удаления записи',
                                 'Не показывать на сайте mkrf.ru', 'дата создания объекта', 'дата обновления объекта']]


New_Labels = ['title',
                                 'title_foreign',
                                 'mkrf_pNum',
                                 'Дата регистрации удостоверения', 'show_start_date', 'description',
                                 'Идентификатор записи реестра', 'annot', 'type', 'film_cat',
                                 'lang', 'Формат кадра', 'count_series',
                                 'Метраж (для фильмов на кинопленке)',
                                 'Количество частей/рулонов (для фильмов на кинопленке)',
                                 'color', 'film_h_lenght',
                                 'film_m_lenght', 'Формат носителя',
                                 'Объем носителя', 'Единица измерения', 'film_studio', 'production_country',
                                 'prod_year', 'director', 'painter', 'screenwriter',
                                 'operator', 'composer',
                                 'producer', 'Права на использование фильма', 'Категория прав на использование фильма',
                                 'Срок действия прав на использование фильма',
                                 'Срок действия прав на способ использования фильма',
                                 'age_limit', 'age_limit_second', 'Дубляж (где дублирован)',
                                 'Срок действия прав проката до',
                                 'Код', 'Права проката переданы', 'Порядковый номер переоформления/продления',
                                 'Должность подписанта',
                                 'ФИО подписанта', 'Запись удалена', 'Дата удаления записи',
                                 'Не показывать на сайте mkrf.ru', 'дата создания объекта', 'дата обновления объекта']





mkrf_true_pNum.columns = New_Labels

# %%
mkrf_true_pNum.columns.tolist()
# Out:
# ['title',
#  'title_foreign',
#  'mkrf_pNum',
#  'Дата регистрации удостоверения',
#  'show_start_date',
#  'description',
#  'Идентификатор записи реестра',
#  'annot',
#  'type',
#  'film_cat',
#  'lang',
#  'Формат кадра',
#  'count_series',
#  'Метраж (для фильмов на кинопленке)',
#  'Количество частей/рулонов (для фильмов на кинопленке)',
#  'color',
#  'film_h_lenght',
#  'film_m_lenght',
#  'Формат носителя',
#  'Объем носителя',
#  'Единица измерения',
#  'film_studio',
#  'production_country',
#  'prod_year',
#  'director',
#  'painter',
#  'screenwriter',
#  'operator',
#  'composer',
#  'producer',
#  'Права на использование фильма',
#  'Категория прав на использование фильма',
#  'Срок действия прав на использование фильма',
#  'Срок действия прав на способ использования фильма',
#  'age_limit',
#  'age_limit_second',
#  'Дубляж (где дублирован)',
#  'Срок действия прав проката до',
#  'Код',
#  'Права проката переданы',
#  'Порядковый номер переоформления/продления',
# ...

# %%
mkrf_true_pNum = mkrf_true_pNum[['title',
 'title_foreign',
 'mkrf_pNum',
 'show_start_date',
 'description',
 'annot',
 'type',
 'film_cat',
 'lang',
 'count_series',
 'color',
 'film_h_lenght',
 'film_m_lenght',
 'film_studio',
 'production_country',
 'prod_year',
 'director',
 'painter',
 'screenwriter',
 'operator',
 'composer',
 'producer',
 'age_limit',
 'age_limit_second']]

# %%
mkrf_true_pNum.describe().T
# Out:
#                  count          mean           std    min          25%  \
# mkrf_pNum      92113.0  1.842112e+08  1.064797e+08  211.0  211002911.0
# lang               4.0  4.475000e+01  6.701990e+00   38.0         39.5
# count_series   36312.0  4.126404e+00  1.262325e+01    0.0          1.0
# film_h_lenght  77362.0  1.815336e+00  4.844285e+00    0.0          1.0
# film_m_lenght  91408.0  3.221424e+01  2.684463e+01    0.0         20.0
#
#                        50%           75%           max
# mkrf_pNum      216000111.0  2.211229e+08  2.210213e+10
# lang                  45.0  5.025000e+01  5.100000e+01
# count_series           1.0  2.000000e+00  6.780000e+02
# film_h_lenght          1.0  2.000000e+00  2.880000e+02
# film_m_lenght         31.0  4.400000e+01  5.454000e+03

# %%
w_df.shape
# Out:
# (7486, 26)

# %% [markdown]
# # разбираемся с дубликатами

# %%
w_df[w_df['puNumber'].isna()]
# Out:
#       puNumber  show_start_year  show_start_month  age_limit  \
# 1797       NaN             2014                 5         12
#
#                              title_true alter_title  \
# 1797  Курбан-роман. (История с жертвой)         NaN
#
#                                   title            type genres  ratings  \
# 1797  Курбан-роман. (История с жертвой)  Художественный    NaN      NaN
#
#       counts_film_studio       film_studio  counts_production_country  \
# 1797                 0.0  ФОНД "ИННОВАЦИЯ"                        0.0
#
#      production_country  counts_director director  counts_producer  \
# 1797             Россия              0.0  С.Юзеев              0.0
#
#         producer financing_source  refundable_support  nonrefundable_support  \
# 1797  М.Галицкая              NaN                 NaN                    NaN
#
#       budget  box_office show_start_date show_start_mnt_yr  \
# 1797     NaN         NaN      2014-05-15          May-2014
#
# ...

# %%
w_df[w_df['title'].str.contains('Курбан-роман')]
# Out:
#          puNumber  show_start_year  show_start_month  age_limit  \
# 1797          NaN             2014                 5         12
# 2078  111009614.0             2014                 9         12
#
#                               title_true alter_title  \
# 1797   Курбан-роман. (История с жертвой)         NaN
# 2078  Курбан-роман. (История с жертвой).         NaN
#
#                                    title            type genres  ratings  \
# 1797   Курбан-роман. (История с жертвой)  Художественный    NaN      NaN
# 2078  Курбан-роман. (История с жертвой).  Художественный    NaN      NaN
#
#       counts_film_studio       film_studio  counts_production_country  \
# 1797                 0.0  ФОНД "ИННОВАЦИЯ"                        0.0
# 2078                 0.0  ФОНД "ИННОВАЦИЯ"                        0.0
#
#      production_country  counts_director director  counts_producer  \
# 1797             Россия              0.0  С.Юзеев              0.0
# ...

# %%
mkrf_true_pNum[mkrf_true_pNum['title'].str.contains('Курбан-роман')]
# Out:
#                                    title title_foreign    mkrf_pNum  \
# 7936   Курбан-роман. (История с жертвой)           NaN          NaN
# 9343  Курбан-роман. (История с жертвой).           NaN  111009614.0
#
#                show_start_date description  annot            type film_cat  \
# 7936  2014-05-15T12:00:00.000Z         NaN    NaN  Художественный     Кино
# 9343  2014-09-02T12:00:00.000Z         NaN  Драма  Художественный     Кино
#
#       lang  count_series    color  film_h_lenght  film_m_lenght  \
# 7936   NaN           1.0  Цветной            1.0           50.0
# 9343   NaN           1.0  Цветной            1.0           50.0
#
#            film_studio production_country prod_year director  \
# 7936  ФОНД "ИННОВАЦИЯ"             Россия      2014  С.Юзеев
# 9343  ФОНД "ИННОВАЦИЯ"             Россия      2014  С.Юзеев
#
#                    painter screenwriter   operator   composer    producer  \
# ...

# %% [markdown]
# как видим можно удалить запись без `puNumber` с индексом 1797

# %%
w_df[w_df['title'].str.contains('Анализируй')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-49dd1f585e60> in <module>
# ----> 1 w_df[w_df['title'].str.contains('Анализируй')]
#
# NameError: name 'w_df' is not defined

# %%
# list(set(temp1) - set(temp2))

current_pnum = set(w_df['puNumber'].tolist())
true_pnum = set(mkrf_true_pNum['mkrf_pNum'].tolist())

print(f'{len(set(current_pnum) & set(true_pnum))} номеров прокатного удостоверенеия есть в обеих таблицах.')
# Out:
# 7483 номеров прокатного удостоверенеия есть в обеих таблицах.

# %%
mkrf_true_box_office.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651 entries, 0 to 650
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   index                   651 non-null    int64
#  1   Название                651 non-null    object
#  2   № ПУ                    640 non-null    float64
#  3   Сборы, руб.             651 non-null    float64
#  4   Тип                     651 non-null    object
#  5   Возрастное ограничение  651 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 30.6+ KB

# %%
mkrf_true_box_office[mkrf_true_box_office['№ ПУ'] == 111000119]
# Out:
#      index  Название         № ПУ  Сборы, руб.             Тип  \
# 311    297  Пилигрим  111000119.0   4293649.51  художественный
#
#             Возрастное ограничение
# 311  «16+» для детей старше 16 лет

# %%
w_df[w_df['title'].str.contains('Русское краткое')]
# Out:
#          puNumber  show_start_year  show_start_month  age_limit  \
# 7060  111011419.0             2019                 7         16
# 7215  111015019.0             2019                 9         18
#
#                                         title_true alter_title  \
# 7060                     Русское краткое. Выпуск 4         NaN
# 7215  Русское краткое. Победители Кинотавра - 2019         NaN
#
#                                              title            type genres  \
# 7060                     Русское краткое. Выпуск 4  Художественный    NaN
# 7215  Русское краткое. Победители Кинотавра - 2019  Художественный    NaN
#
#       ratings  counts_film_studio  \
# 7060      5.2                 2.0
# 7215      NaN                 4.0
#
#                                             film_studio  \
# 7060  ИП Дибцева О.Н., ИП Булгаков Д.А., ООО "Киноко...
# 7215  ООО Компания "Новые люди", ООО "Кинокомпания Д...
#
# ...

# %%
# mkrf_true_box_office['№ ПУ'] = pd.to_numeric(mkrf_true_box_office['№ ПУ'], errors='coerce')

# current_pnum = set(w_df['puNumber'].tolist())
# check_pnum = set(mkrf_true_box_office['№ ПУ'].tolist())

# print(f'{len(set(current_pnum) & set(check_pnum))} номеров прокатного удостоверенеия есть в обеих таблицах.')

# %% [markdown]
# Решим проблему дублей в файле источнике по столбцу `puNumber` с помощь данных открытых МК РФ
#
# Очевидный дубль `Анализируй это!`

# %%
w_df[w_df.duplicated(subset='puNumber', keep=False)]
# Out:
#          puNumber  show_start_year  show_start_month  age_limit  \
# 4638  221154310.0             2010                12         16
# 4639  221154310.0             2010                12         16
# 5067  221054410.0             2010                 5         16
# 5068  221054410.0             2010                 5         12
#
#                                 title_true                       alter_title  \
# 4638      Как жениться и остаться холостым                               NaN
# 4639  Иоанна - женщина на папском престоле  /По роману Донны Вулфольк Кросс/
# 5067                       Анализируй это!                               NaN
# 5068                        Анализируй то!                               NaN
#
#                                                   title            type  \
# 4638                   Как жениться и остаться холостым  Художественный
# 4639  Иоанна - женщина на папском престоле /По роман...  Художественный
# ...

# %%
mkrf_true_pNum[mkrf_true_pNum['mkrf_pNum'] == 221054410]
# Out:
#                  title  title_foreign    mkrf_pNum           show_start_date  \
# 35225  Анализируй это!   Analyze This  221054410.0  2010-05-25T12:00:00.000Z
# 35226   Анализируй то!  Analyze That!  221054410.0  2010-05-25T12:00:00.000Z
#
#       description                                              annot  \
# 35225         NaN  В ролях: Роберт Де Ниро, Билли Кристал. Комеди...
# 35226         NaN  В гл.роли Роберт Де Ниро. Комедия.  Новая верс...
#
#                  type film_cat  lang  count_series    color  film_h_lenght  \
# 35225  Художественный     Кино   NaN           1.0  Цветной            1.0
# 35226  Художественный     Кино   NaN           1.0  Цветной            1.0
#
#        film_m_lenght                                        film_studio  \
# 35225           43.0          Уорнер Бразерс, Вилладж Роудшоу Филмз ЛТД
# 35226           35.0  Уорнер Бразерс, Виллидж Роадшоу Пикчерз, Эн-Пи...
#
#       production_country prod_year        director     painter  \
# ...

# %%
mkrf_true_box_office.shape
# Out:
# (651, 8)

# %%
first_merge = w_df.merge(mkrf_true_box_office,
                         how='left',
                         left_on='puNumber',
                         right_on='№ ПУ')

first_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7496 entries, 0 to 7495
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   puNumber                   7485 non-null   float64
#  1   show_start_year            7496 non-null   int64
#  2   show_start_month           7496 non-null   int64
#  3   age_limit                  7496 non-null   int64
#  4   title_true                 7496 non-null   object
#  5   alter_title                464 non-null    object
#  6   title                      7496 non-null   object
#  7   type                       7496 non-null   object
#  8   genres                     6510 non-null   object
#  9   ratings                    6490 non-null   float64
#  10  counts_film_studio         7478 non-null   float64
#  11  film_studio                7478 non-null   object
#  12  counts_production_country  7494 non-null   float64
# ...

# %%
first_merge_up = first_merge.groupby(['Название', 'count_pu']).size().reset_index(name='pu_count')

# %%
first_merge_up[(first_merge_up['count_pu'] > 1) &
           (~first_merge_up['pu_count'].isna())].sample(5).T
# Out:
#                                         181        323  \
# Название  Звёздные войны: Скайуокер. Восход  Невиновен
# count_pu                                2.0        2.0
# pu_count                                  1          2
#
#                                                         294  \
# Название  Маша и Медведь (Летние каникулы с Машей и Медв...
# count_pu                                                4.0
# pu_count                                                  3
#
#                           13            534
# Название  Ford против Ferrari  Фабрика грёз
# count_pu                  2.0           2.0
# pu_count                    1             2

# %%
first_merge['count_pu'] = first_merge.groupby('idx_up_count_pu')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-207-d731e4588576> in <module>
# ----> 1 first_merge['count_pu'] = first_merge.groupby('idx_up_count_pu')
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3605         else:
#    3606             # set column
# -> 3607             self._set_item(key, value)
#    3608
#    3609     def _setitem_slice(self, key: slice, value):
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3777         ensure homogeneity.
#    3778         """
# -> 3779         value = self._sanitize_column(value)
#    3780
#    3781         if (
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4502
#    4503         if is_list_like(value):
# ...

# %%
first_merge[(first_merge['count_pu'] > 1) &
           (first_merge['box_office'].isna())]['count_pu'] =
# Out:
# (32, 34)

# %%
first_merge.describe().T
# Out:
#                             count          mean           std          min  \
# puNumber                   7485.0  1.351966e+08  3.835292e+07    1811096.0
# show_start_year            7496.0  2.014593e+03  3.006522e+00       2010.0
# show_start_month           7496.0  7.043490e+00  3.547595e+00          1.0
# age_limit                  7496.0  1.300667e+01  5.600911e+00          0.0
# ratings                    6490.0  6.479245e+00  1.101665e+00          1.0
# counts_film_studio         7478.0  1.834047e+00  2.419081e+00          0.0
# counts_production_country  7494.0  3.666934e-01  8.553711e-01          0.0
# counts_director            7487.0  2.326700e-01  9.535491e-01          0.0
# counts_producer            6928.0  1.432592e+00  1.451717e+00          0.0
# refundable_support          332.0  1.186446e+07  2.491656e+07          0.0
# nonrefundable_support       332.0  4.898099e+07  5.998012e+07          0.0
# ...

# %%
df_list = [w_df,
mkrf_true_pNum,
mkrf_true_box_office,

# %%
mkrf_true_pNum.describe(include='all').T
# Out:
#                                                       count  unique  \
# Название фильма                                       93927   77832
# Hаименование на иностранном языке                     48530   31266
# Номер удостоверения                                 92113.0     NaN
# Дата регистрации удостоверения                        93925    5721
# Дата начала показа фильма                             93622    6089
# Примечание                                            29185    6986
# Идентификатор записи реестра                        93927.0     NaN
# Аннотация                                             88138   50907
# Вид Фильма                                            93922      14
# Категория                                             93927       4
# Язык оригинала                                          4.0     NaN
# Формат кадра                                          13322     329
# Количество серий                                    36312.0     NaN
# ...

# %%
# удалим строку с индексом 5068
w_df = w_df.drop(5068)
w_df[w_df.duplicated(subset='puNumber', keep=False)]
# Out:
#                                                   title   puNumber  \
# 4638                   Как жениться и остаться холостым  221154310
# 4639  Иоанна - женщина на папском престоле /По роман...  221154310
#
#      show_start_date            type  \
# 4638      2010-12-17  Художественный
# 4639      2010-12-17  Художественный
#
#                                             film_studio  \
# 4638  Ше Вам, Скрипт Ассосье, Тэ Фэ 1 Фильм Продюксь...
# 4639   Константин Фильм, А Эр Ди Дегето Фильм, Дюне ...
#
#                                 production_country        director  \
# 4638                                       Франция    Эрик Лартиго
# 4639  Германия - Великобритания - Италия - Испания  Зенке Вортманн
#
#                                         producer  \
# 4638                     Амандин Било, Алан Шаба
# 4639  Оливер Бербен, Дорис Д.Хайнце, Фарук Элтан
#
#                       age_restriction  refundable_support  \
# ...

# %% [markdown]
# Другая пара явно разные фильмы, мы не хотим пока терять данные, поэтому просто добавим дополнительный символ в один из номеров прокатного удостоверения (предварительно убедимя, что номер станет уникальным), но запмним это на будующее - убедимся в правомерности решения позже, при общении с заказчиком.

# %%
w_df.loc[4639,'puNumber'] = '2211543102'

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера</b>
#
# Нам следует избегать хардкода - введённых вручную параметров. Представь, если данные поменяются, или мы сбросим индекс (в следующих версиях проекта), то мы можем удалить другой фильм. Пожалуйста, сформулируй запросы так, чтобы мы не зависели от индекса.
#
# Помимо этого, у меня есть еще ряд замечаний к этому блоку:
# - Мы обнаружили, что под одним удостоверением у нас в базе две пары фильмов. Одна из них, как мы предположили, дубликат. Но, давай посмотрим на данные выше детальнее - у этих фильмов разные режиссёры, страны, возрастная категория. Может быть все же это разные фильмы? Удивительно, но ответ ты сам показал - по ссылке у Кинопоиска есть раздел `Сиквелы и приквелы` и там представлен второй фильм, который мы в итоге удалили. Оказывается, это два разных фильма! Просто авторы так обыграли название.
# - Очень хорошо, что мы проверили дубликаты по номеру удостоверения, но давай посмотрим дубликаты по названию фильма. Тоже достаточно важный критерий. В целом, когда ты выводил  `describe()` по сырым данным количество дубликатов было уже видно. Можно еще раз проверить и предположить причины возникновения, а также предложить, что мы будем делать с этими данными.
#
# </div>

# %%
mkrf_merge[mkrf_merge['title'] == 'Анализируй то!'].T
# Out:
#                                                                     5068
# title                                                     Анализируй то!
# puNumber                                                       221054410
# show_start_date                                 2010-05-25T12:00:00.000Z
# type                                                      Художественный
# film_studio            Уорнер Бразерс, Виллидж Роадшоу Пикчерз, Эн-Пи...
# production_country                                                   США
# director                                                  Гарольд Реймис
# producer                                 Джейн Розенталь, Паул Уэйнстейн
# age_restriction                          «12+» - для детей старше 12 лет
# refundable_support                                                   NaN
# nonrefundable_support                                                NaN
# budget                                                               NaN
# ...

# %%
mkrf_true_id[mkrf_true_id['Название фильма'] == 'Анализируй то!'].T
# Out:
#                                                                                                 35226  \
# Название фильма                                                                        Анализируй то!
# Hаименование на иностранном языке                                                       Analyze That!
# Номер удостоверения                                                                         221054410
# Дата регистрации удостоверения                                               2010-05-25T12:00:00.000Z
# Дата начала показа фильма                                                    2010-05-25T12:00:00.000Z
# Примечание                                                                                        NaN
# Идентификатор записи реестра                                                                  2194549
# Аннотация                                           В гл.роли Роберт Де Ниро. Комедия.  Новая верс...
# ...

# %%
mkrf_true_id[['Название фильма',
              'Номер удостоверения']].head()
# Out:
#         Название фильма Номер удостоверения
# 0        Почти знаменит           221006316
# 1        Открытое окно.           221027814
# 2      Открытый простор           221048915
# 3  Особо важное задание           111013716
# 4          Особо опасен           221038416

# %%
# Out:
# 6792

# %%
film_matches = [x for x in mkrf_true_id['Название фильма'].tolist() if x in mkrf_merge['title'].tolist()]

# %%
len(film_matches)
# Out:
# 9849

# %%
mkrf_true_id[mkrf_true_id['Название фильма'] == 'Особо опасен'].T
# Out:
#                                                                                                 4      \
# Название фильма                                                                          Особо опасен
# Hаименование на иностранном языке                                                              Wanted
# Номер удостоверения                                                                         221038416
# Дата регистрации удостоверения                                               2016-10-10T12:00:00.000Z
# Дата начала показа фильма                                                    2016-10-10T12:00:00.000Z
# Примечание                                                                                        NaN
# Идентификатор записи реестра                                                                  2157031
# Аннотация                                           В ролях: Джеймс МакЭвой, Анджелина Джоли. Тайн...
# ...

# %%
film_matches[:5]
# Out:
# ['Открытый простор',
#  'Особо важное задание',
#  'Особо опасен',
#  'Особо опасен',
#  'Особо опасен']

# %%
mkrf_merge[mkrf_merge['title'] == 'Особо опасен'].T
# Out:
#                                                                        2  \
# title                                                       Особо опасен
# puNumber                                                       221038416
# show_start_date                                 2016-10-10T12:00:00.000Z
# type                                                      Художественный
# film_studio            Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...
# production_country                                                   США
# director                                               Тимур Бекмамбетов
# producer               Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# age_restriction                              «18+» - запрещено для детей
# refundable_support                                                   NaN
# nonrefundable_support                                                NaN
# budget                                                               NaN
# ...

# %%
film_matches_second = [x for x in mkrf_merge['title'].tolist() if x in mkrf_true_id['Название фильма'].tolist()]
len(film_matches_second)
# Out:
# 7486

# %% [markdown]
# Видим еще одно странное значение, так же исправим произвольным номером.

# %%
w_df[w_df['puNumber'] == '0']
# Out:
# Empty DataFrame
# Columns: [title, puNumber, show_start_date, type, film_studio, production_country, director, producer, age_restriction, refundable_support, nonrefundable_support, budget, financing_source, ratings, genres, box_office, title_true, first_lv_desc, second_lv_desc, alter_title, title_true_len, show_start_year, show_start_month, age_limit, counts_film_studio, counts_production_country, counts_director, counts_producer]
# Index: []

# %%
w_df.loc[1797,'puNumber'] = '0'

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера</b>
#
# Тут тоже самое - лучше провесит замену строк, где номер удостоверения указан как `нет`. Пожалуйста, подправь этот момент.
#
# </div>

# %%
w_df['puNumber'] = pd.to_numeric(w_df['puNumber'], errors='raise')

# %%
w_df = w_df.set_index('puNumber')
w_df.sample(3).T
# Out:
# puNumber                                                126002711  \
# title                      Питер Гэбриэл и New Blood Orchestra 3D
# show_start_date                                        2011-11-11
# type                                                       Прочие
# film_studio                                       Омниверс Визион
# production_country                                 Великобритания
# director                                                      NaN
# producer                                          Омниверс Визион
# age_restriction            «0+» - для любой зрительской аудитории
# refundable_support                                            NaN
# nonrefundable_support                                         NaN
# budget                                                        NaN
# financing_source                                              NaN
# ratings                                                       6.7
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера</b>
#
# Отличная идея! Очень классно, что ты нашел данные, которые мы можем использовать, но ...
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера</b>
#
# Но, где-же реализация задуманного?
#
# ---
#
# Нам лучше как-то систематизировать работу с пропусками в этом блоке. Сперва можно подсчитать процент пропусков для каждого столбца. Затем рассмотреть – есть ли какие-то закономерности в пропусках? После этого мы можем уже более детально посмотреть на пропуски и предложить, что с ними делать (как их обрабатывать). Например, была отличная идея использовать внешние базы данных для заполнения пропусков в столбце жанры. Тогда эту идею нужно реализовать в этом блоке.
#
# В заключении нам следует сделать небольшой вывод, где указать, что было и как стало. Пожалуйста, дополни эту часть проекта.
#
# </div>

# %% [markdown]
# ### 2.1.  Посчитайте динамику сборов по годам премьер фильмов. В каком году медианная сумма сборов была максимальной?
#
#
# <a class="anchor" id="basic_task_1"></a>
# [<назад](#basic_task_0) | [оглавление](#contents) | [дальше>](#basic_task_2)

# %%
box_median_dict = {}

for year in sorted(w_df['show_start_year'].unique().tolist()):
    box_median = w_df[w_df['show_start_year'] == year]['box_office'].median()
    box_median_dict[year] = box_median
    print(f'{year} медианная сумма сборов: {box_median}\n')
    
print('Максимальная медиианная сумма сборов была в', max(box_median_dict, key=box_median_dict.get), ' году.')
# Out:
# 2010 медианная сумма сборов: 1700.0
#
# 2011 медианная сумма сборов: 3000.0
#
# 2012 медианная сумма сборов: 5660.0
#
# 2013 медианная сумма сборов: 3522.5
#
# 2014 медианная сумма сборов: 18160.0
#
# 2015 медианная сумма сборов: 4920933.0
#
# 2016 медианная сумма сборов: 3846679.41
#
# 2017 медианная сумма сборов: 9968340.0
#
# 2018 медианная сумма сборов: 8891102.21
#
# 2019 медианная сумма сборов: 4627798.345
#
# Максимальная медиианная сумма сборов была в 2017  году.

# %% [markdown]
# Вывод

# %% [markdown]
# ### 2.2. С помощью сводной таблицы определить среднюю и медианную сумму сборов для каждого года.
# <a class="anchor" id="basic_task_2"></a>
#
# [<назад](#basic_task_1) | [оглавление](#contents) | [дальше>](#basic_task_3)

# %%
w_df['box_office_mean'] = w_df['box_office']
w_df['box_office_median'] = w_df['box_office']

pivot_mean_and_median_box = pd.pivot_table(w_df, values=['box_office_mean',
                                                         'box_office_median'], index=['show_start_year'],
                    aggfunc={'box_office_mean': np.mean,
                             'box_office_median': np.median})

pivot_mean_and_median_box.astype('int64')
# Out:
#                  box_office_mean  box_office_median
# show_start_year
# 2010                       23130               1700
# 2011                      129383               3000
# 2012                       54339               5660
# 2013                      161954               3522
# 2014                    26684415              18160
# 2015                    84940570            4920933
# 2016                    91000569            3846679
# 2017                   136032793            9968340
# 2018                   104565059            8891102
# 2019                    91369261            4627798

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера</b>
#
# С одной стороны - среднее значение и медиана для каждого года подсчитаны.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера</b>
#
# В этом блоке не хватает выводов и немного более детального анализа данных. Также, эти данные лучше визуализировать - заказчику будет комфортнее их изучать.
#
# Старайся к каждому логически завершенному блоку предоставлять промежуточные выводы. Так будет понятнее заказчику или коллегам, что мы получили и соответствует ли то, что мы получили нашим ожиданиям. Лучше не оставлять заказчика один на один с результатами или графиками – нам надо объяснить полученные результаты и их значимость.
#
# Давай посмотрим на результаты - среднее значение отличается от медианы, а это означает, что данные имеют перекос в одну из сторон (в сторону больших или меньших значений), значит мы можем допускать, что в данных могут быть какие-то аномальные значения. Например, в году с самыми большими сборами вышел какой-то новый шедевр, и собственно этот фильм обеспечил хорошие цифры. Такие вещи лучше дополнительно исследовать - самый простой способ оценить аномалии построив боксплоты. Также, значение медианы резко увеличивается в 2015 году - это надо как-то объяснить.
#
# Также не ясно, какое количество фильмов по годам премьеры мы сравниваем.
#
# Добавь, пожалуйста, выводы к этой части проекта.
#
# </div>

# %% [markdown]
# Вывод

# %% [markdown]
# ### 2.3. У кого из продюссеров самый высокий средний рейтинг фильмов?
# <a class="anchor" id="basic_task_3"></a>
#
# [<назад](#basic_task_2) | [оглавление](#contents) | [дальше>](#basic_task_4)

# %%
producers_average_rating = w_df[['title_true','producer','ratings']]
producers_average_rating.head(2)
# Out:
#                      title_true                                   producer  \
# puNumber
# 221048915      Открытый простор  Дэвид Валдес, Кевин Костнер, Джейк Эбертс
# 111013716  Особо важное задание                                        NaN
#
#            ratings
# puNumber
# 221048915      7.2
# 111013716      6.6

# %%
producers_average_rating.shape
# Out:
# (7485, 3)

# %%
producers_average_rating = producers_average_rating.dropna()
producers_average_rating.shape
# Out:
# (6011, 3)

# %%
producers_average_rating['producer'] = producers_average_rating['producer'].str.split(',')
producers_average_rating.head(2)
# Out:
#                  title_true  \
# puNumber
# 221048915  Открытый простор
# 221038416      Особо опасен
#
#                                                     producer  ratings
# puNumber
# 221048915      [Дэвид Валдес,  Кевин Костнер,  Джейк Эбертс]      7.2
# 221038416  [Джим Лемли,  Джейсон Нетер,  Марк Е.Платт,  Я...      6.8

# %%
producers_average_rating_explode = producers_average_rating.explode('producer').drop_duplicates()
producers_average_rating_explode = producers_average_rating_explode.reset_index()
producers_average_rating_explode.shape
# Out:
# (13156, 4)

# %%
producers_average_rating_explode.head(2)
# Out:
#     puNumber        title_true        producer  ratings
# 0  221048915  Открытый простор    Дэвид Валдес      7.2
# 1  221048915  Открытый простор   Кевин Костнер      7.2

# %%
pivot_producers_average_rating = pd.pivot_table(producers_average_rating_explode, values='ratings',
                                                                                     index=['producer'],
                    aggfunc={'ratings': np.mean})


pivot_producers_average_rating.sort_values(by='ratings', ascending=False).head(10)
# Out:
#                           ratings
# producer
#  Ники Марвин                  9.1
#  Дэвид В.Лестер               9.1
#  Ю.Осетинская                 9.0
# Э Мультимедиа Еуроп Филм      8.8
#  Мокер Продакшн               8.8
#  Куин Филмз Презент           8.8
#  Э Мэфилм Дайлог Студио       8.8
#  Карен Гилкрайст              8.8
# В.Меньшов                     8.8
# Джон Фавро                    8.8

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера</b>
#
# Хорошо, данные по режиссёрам мы получили. Я немного не понял про пропуски в режиссёрах - в итоге мы их удалили, но как-то не проанализировав эти пропуски.
# </div>

# %% [markdown]
# ### Результат не очень отражает суть, победители сняли лишь один фильм(

# %%
w_df[(w_df['producer'].notna()) & (w_df['producer'].str.contains('Ники Марвин'))].T
# Out:
# puNumber                                                       121029519
# title                                                  Побег из Шоушенка
# show_start_date                                               2019-10-18
# type                                                      Художественный
# film_studio                Уорнер Броз. Пикчерз, Кастл Рок Интертейнмент
# production_country                                                   США
# director                                                  Фрэнк Дарабонт
# producer                         Лиз Глоцер, Дэвид В.Лестер, Ники Марвин
# age_restriction                          «16+» - для детей старше 16 лет
# refundable_support                                                   NaN
# nonrefundable_support                                                NaN
# budget                                                               NaN
# financing_source                                                     NaN
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера</b>
#
# Действительно, результаты не впечатляют. В этом блоке  не хватает комментариев или выводов. Пожалуйста, добавь их. Также возникают такие вопросы:
# - данные по продюсерам имеют разный вид, например, где-то имя прописано полностью, а где сокращено. Не может ли быть дублирование данных в этом случае, когда один и тот же продюсер имеет полное имя или сокращенное? Лучше проверить и привести все к единому виду;
# - данные показывают, что у одного фильма может быть несколько продюсеров. Но, может быть в таком случае нам лучше учитывать только первого продюсера?
# - ты отлично показал, что нам надо еще учитывать количество фильмов (и количество коллег-продюсеров?), чтобы была более-менее объективная картина; подумай, пожалуйста, как мы можем модернизировать рейтинг продюсеров?
# </div>

# %% [markdown]
# # Задачи от бизнеса

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера</b>
#
# Дальше я не смотрел, поскольку это все в черновом виде. Пожалуйста, учитывай комментарии по оформлению тетрадки и в новой части кода.</div>

# %% [markdown]
# 1. Какой жанр имеет наибольший рейтинг? Учитывайте все жанры, к которым относится фильм. (задача на посчитать)

# %%
w_df_ganres = w_df[~w_df['genres'].isna()]

# %%
w_df_ganres['genres_list'] = w_df_ganres['genres'].str.split(',')
# Out:
# <ipython-input-41-3361362ab258>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w_df_ganres['genres_list'] = w_df_ganres['genres'].str.split(',')

# %%
w_df_ganres_explode = w_df_ganres.explode('genres_list').drop_duplicates()
w_df_ganres_explode = w_df_ganres_explode.reset_index()
w_df_ganres_explode.shape
# Out:
# (15211, 31)

# %%
top_ganres = pd.pivot_table(w_df_ganres_explode, values='ratings',
                                                                                     index=['genres_list'],
                    aggfunc={'ratings': np.mean})


top_ganres.sort_values(by='ratings', ascending=False).head(10)
# Out:
#                   ratings
# genres_list
# новости          7.800000
# аниме            7.443836
# документальный   7.202632
# концерт          7.165000
# короткометражка  7.066038
# биография        7.040968
# мюзикл           6.993636
# спорт            6.961458
# вестерн          6.906250
# военный          6.905584

# %%
w_df[(w_df['genres'].notna()) & (w_df['genres'].str.contains('новости'))].T
# Out:
# puNumber                                                           126003515
# title                                                     Реальная цена моды
# show_start_date                                                   2015-11-25
# type                                                                  Прочие
# film_studio                Антолд Креатив, Лайф Ис Май Муви Интертейнмент...
# production_country         Великобритания - Франция - Италия - Индия - Да...
# director                                                        Эндрю Морган
# producer                   Винсент Витторио, Ливия Джуджолли, Майкл Росс,...
# age_restriction                              «16+» - для детей старше 16 лет
# refundable_support                                                       NaN
# nonrefundable_support                                                    NaN
# budget                                                                   NaN
# ...

# %% [markdown]
# ### <font color='green'>выделил задачки с которыми хочу поработать</font>
#
# 2. Велик ли объем господдержки в фильмах? (надо посчитать долю для каждого фильма и обосновать много это или мало)
#
# 3. Какие фильмы лучше - с господдержкой или без? (надо предложить и обосновать понятие "лучше")
#
# 4. Составьте список успешных режиссеров. (предложить и обосновать понятие успешности)
#
# ### <font color='green'>5. Каких продюсеров можно назвать "восходящими звездами кинематографа?" (предложить показатель успешности и проанализовать динамику этого показателя)</font>
#
# ### <font color='green'>6. Влияет ли возрастное ограничение на успех фильма?</font>
#
# ### <font color='green'>7. Решите проблемы с пропусками в данных с помощью внешних источников.</font>
#
# ### <font color='green'>8. Сейчас наши коллеги-аналитики работают с данными в Экселе и тратят много времени на обработку. Данные проекта - результат из работы. Ваша задача указать проблемы в данных, которые они упустили. И показать преимущества pandas для подобных задач.</font>
#
# ### <font color='green'>9. Постройте модель предсказания будущего рейтинга фильма или успешности в финансовых показателях.</font>
#
#
# ## Пока не до конца успел сформулировать свои дальнейшие шаги, в общих чертах:
#
# 1. хочу разместить БД по фильмам в Google Cloude;
#
# 2. в БД накапливать/парсить данные - использовать Silenium;
#
# 3. там же собрать модель для оценки успешных продюссеров и продюссерских коллективов.
